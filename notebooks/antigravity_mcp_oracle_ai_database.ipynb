# %% [markdown]
# # Antigravity MCP with Oracle AI Database Workflow
#
# Use this notebook as the Antigravity-first path for connecting an AI coding agent to Oracle AI Database through SQLcl MCP.
#
# The goal is not to give Antigravity invisible database access. The goal is the opposite: make each database action an explicit MCP tool call, keep Oracle privileges in charge, and preserve the durable memory and retrieval evidence inside Oracle AI Database.
#
# By the end, you will have three concrete artifacts:
#
# - a validated SQLcl saved connection named `antigravity_mcp`;
# - an Antigravity MCP preview file at `antigravity_sqlcl_mcp_config.preview.json`;
# - Oracle-backed memory tables, retrieval checks, and prompt evidence you can inspect.
#
# The notebook does not call Antigravity from Python. Antigravity runs the agent experience and launches SQLcl as a local MCP server from `mcp_config.json`; Python validates the database, memory, retrieval, and configuration layer so the live Antigravity step is small and reviewable.

# %% [markdown]
# ## Antigravity Quick Start
#
# Keep these values visible while you run the notebook:
#
# | Item | Value |
# | --- | --- |
# | SQLcl saved connection | `antigravity_mcp` |
# | Optional alias env var | `ANTIGRAVITY_SQLCL_CONNECTION_NAME=antigravity_mcp` |
# | Preview artifact | `antigravity_sqlcl_mcp_config.preview.json` |
# | Global Antigravity MCP config | `~/.gemini/config/mcp_config.json` |
# | Workspace Antigravity MCP config | `.agents/mcp_config.json` |
#
# The notebook writes only a preview MCP config. After it runs, review the preview, copy the `mcpServers.sqlcl` block into either the global or workspace Antigravity config, reload MCP servers, and ask a read-only question before trying anything that changes data.
#
# Use `ANTIGRAVITY_SQLCL_CONNECTION_NAME` when you want Antigravity-specific SQLcl alias settings without changing the shared `SQLCL_CONNECTION_NAME` used by the older notebooks.

# %% [markdown]
# ## What You Will Learn
#
# - How Antigravity CLI uses SQLcl MCP as an explicit Oracle AI Database tool boundary.
# - How to generate and validate the Antigravity MCP configuration artifacts.
# - How to store Antigravity/MCP conversation traces, tool logs, and retrieval memory in Oracle AI Database.
# - How to classify MCP tool calls before they are treated as safe to execute.
# - How to run lexical search, vector search, and hybrid retrieval over the same memory layer.
# - How to create evidence packages and LangChain-compatible documents from Oracle AI Database memory.

# %% [markdown]
# ## Architecture at a Glance
#
# ```text
#                          +--------------------------+
#                          |      Human operator      |
#                          +------------+-------------+
#                                       | asks / reviews
#                                       v
# +------------------------------------------------------------------+
# |                       Antigravity CLI                           |
# |  Intent, planning, conversation continuity, MCP client behavior  |
# +------------+---------------------------------------+-------------+
#              | Loop A: explicit MCP tool call        | grounded context
#              v                                       |
# +--------------------------+                         |
# |     SQLcl MCP Server     |                         |
# |        `sql -mcp`        |                         |
# |  saved SQLcl connection  |                         |
# +------------+-------------+                         |
#              | SQL execution through declared tools  |
#              v                                       |
# +----------------------------------------------------+-------------+           +------------------------------+
# |                      Oracle AI Database                           |   < ---  |   Oracle AI Agent Memory     |
# |  privileges  |  SQL/JSON memory  |  Oracle Text  |  VECTOR search |          |     (Python package)         |
# +------------+---------------------------------------+-------------+           +------------------------------+
#              | Loop B: durable memory + retrieval    |
#              v                                       v
# +--------------------------+           +--------------------------+
# | Conversation + tool logs |           |   Retrieval evidence     |
# | MCP traces, status,      |           |   lexical + vector +     |
# | errors, tenant metadata  |           |   metadata filtering     |
# +--------------------------+           +------------+-------------+
#                                                    | optional wrapper
#                                                    v
#                                       +--------------------------+
#                                       |        LangChain         |
#                                       | retrieval orchestration  |
#                                       +--------------------------+
# ```
#
# The important boundary is MCP: Antigravity does not receive implicit database access. It receives a declared SQLcl MCP tool surface, while Oracle AI Database remains responsible for data access, privileges, durable memory, and retrieval.
#
# This notebook validates the Oracle AI Database memory and retrieval layer directly, then prepares the artifacts needed for live Antigravity MCP validation: the MCP config preview, the SQLcl saved-connection check, and the manual Antigravity CLI test.

# %% [markdown]
# ## Workflow Overview
#
# 1. Load and verify the FreeSQL Oracle Database connection.
# 2. Validate the local Antigravity CLI + SQLcl MCP setup path.
# 3. Generate the Antigravity `mcp_config.json` MCP config preview.
# 4. Create Oracle AI Database memory tables.
# 5. Insert a realistic Antigravity + MCP workflow.
# 6. Inspect tool traces and controlled failures.
# 7. Run lexical, vector, and hybrid retrieval.
# 8. Visualize retrieval scores and MCP tool decisions.
# 9. Generate Antigravity-ready evidence and prompt artifacts.
# 10. Wrap retrieval with LangChain.
# 11. End with a compact validation snapshot.

# %% [markdown]
# ## Setup and Database Connection
#
# This notebook is configured for a FreeSQL-hosted Oracle AI Database schema. FreeSQL lets the notebook run against a real Oracle Database service without starting a local container.
#
# You should have:
#
# - Python 3.10+
# - A FreeSQL schema from [freesql.com](https://freesql.com)
# - `oracledb`, `python-dotenv`, `pandas`, `numpy`, and `matplotlib` packages installed
# - Oracle SQLcl 25.2+ for SQLcl MCP workflows
# - Oracle JRE 17 or 21 for SQLcl MCP workflows
# - Antigravity IDE or Antigravity CLI if you want to use the generated MCP configuration outside this notebook
# - A saved SQLcl connection named `antigravity_mcp` for MCP usage, created locally with `-savepwd`
#
# Optional integration packages:
# - `oracleagentmemory` package (Step 15 - Oracle AI Agent Memory)
# - `langchain-core`, `langchain`, `langchain-community`, and `langchain-oracledb` packages (Step 16 - LangChain)
#
# The FreeSQL path uses the normal `python-oracledb` connection first, then validates the Antigravity-specific SQLcl/MCP layer separately. The package-backed Oracle Agent Memory managed-schema step is optional on FreeSQL because it can require admin-granted scheduler privileges.

# %% [markdown]
# ## Option A - FreeSQL Connection Setup
#
# Use this path when you want a hosted Oracle Database schema without setting up Podman, Docker, or a local database.
# FreeSQL gives developers a quick Oracle Database schema at freesql.com.
#
# Set these values as environment variables before running the notebook:
#
# ```env
# ORACLE_USER=<FreeSQL schema username>
# ORACLE_PASSWORD=<generated FreeSQL schema password>
# ORACLE_DSN=tcps://db.freesql.com:2484/<FreeSQL service name>
# # DB_DSN is also accepted as an alias for DB_CONNECT_STRING.
# ```
#
# FreeSQL setup steps:
#
# 1. Sign in to [FreeSQL](https://freesql.com).
# 2. Open **Connect to the Database**.
# 3. Choose **Python**.
# 4. Copy the generated username, password, and DSN/connect descriptor.
# 5. Add them to your private `.env` file.
#
# This notebook accepts either the Antigravity variable names:
#
# ```env
# ORACLE_USER=<freesql-user>
# ORACLE_PASSWORD=<freesql-password>
# ORACLE_DSN=<freesql-python-dsn>
# ```
#
#
# **Setup flow**
#
# `FreeSQL credentials` -> `python-oracledb connection` -> `table-permission check` -> `SQLcl saved connection` -> `Antigravity MCP config` -> `Oracle-backed memory and retrieval workflow`
#
# The connection preflight below confirms that the hosted schema works before the notebook creates the Antigravity memory tables. It prints only readiness status and never displays usernames, passwords, DSNs, database versions, or local paths.

# %% [markdown]
# ## Option B - Optional Fallback: Standalone Oracle Database Setup with Docker
#
# Use Oracle Database Free in Docker when you want a reproducible local database for the full example instead of FreeSQL.
#
# ```bash
# docker pull gvenzl/oracle-free:23.26.2
# docker volume create oracle-free-data
#
# docker run -d \
#   --name oracle-ai-memory-example \
#   -p 1522:1521 \
#   -e ORACLE_PASSWORD="<admin-password>" \
#   -e APP_USER="<app-user>" \
#   -e APP_USER_PASSWORD="<app-password>" \
#   -v oracle-free-data:/opt/oracle/oradata \
#   gvenzl/oracle-free:23.26.2
#
# docker logs -f oracle-ai-memory-example
# ```
#
# Then configure the active connection:
#
# ```env
# DB_USER=<app-user>
# DB_PASSWORD=<app-password>
# DB_CONNECT_STRING=localhost:1522/FREEPDB1
# ```
#
# For this executed notebook, the active path is FreeSQL. The Docker path is included only as a local fallback for readers who want to run the same workflow without the hosted FreeSQL service.

# %% [markdown]
# ## Runtime Configuration
#
# The notebook needs one Oracle Database connection and one local SQLcl runtime for the MCP handoff.
#
# | Variable | Purpose |
# |---|---|
# | `ORACLE_USER` or `DB_USER` | FreeSQL schema user |
# | `ORACLE_PASSWORD` or `DB_PASSWORD` | FreeSQL schema password |
# | `ORACLE_DSN`, `DB_CONNECT_STRING`, or `DB_DSN` | FreeSQL Python DSN/connect string |
# | `SQLCL_PATH` | Local standalone SQLcl executable used by Antigravity MCP |
# | `SQLCL_CONNECTION_NAME` or `ANTIGRAVITY_SQLCL_CONNECTION_NAME` | Saved SQLcl connection alias, normally `antigravity_mcp` |
# | `TNS_ADMIN` | Optional folder containing `tnsnames.ora` when SQLcl needs a local TNS entry |
#
# The deterministic embedding demo does not require an OpenAI API key or model billing.

# %% [markdown]
# ## Load Local Environment Values
#
# This cell loads local environment values from the project `.env` file. The values can use either the Antigravity `ORACLE_*` names or the FreeSQL-style `DB_*` aliases shown above.

# %%
# Verify dependencies (safe to re-run, offline-friendly)
from importlib import util
from pathlib import Path


def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / "requirements.txt").exists() and (candidate / ".env").exists():
            return candidate
    return start


PROJECT_ROOT = find_project_root(Path.cwd())

required_modules = [
    "oracledb",
    "dotenv",
    "pandas",
    "numpy",
    "matplotlib",
    "ipykernel",
]
optional_modules = [
    "oracleagentmemory",
    "langchain",
    "langchain_core",
    "langchain_community",
    "langchain_oracledb",
]

missing_required = [module for module in required_modules if util.find_spec(module) is None]
missing_optional = [module for module in optional_modules if util.find_spec(module) is None]

if missing_required:
    raise RuntimeError(f"Missing required Python modules: {missing_required}")

print("Base dependencies available.")
if missing_optional:
    print(f"Optional modules unavailable: {missing_optional}. Optional sections will run in fallback mode.")
else:
    print("Optional dependencies available.")

requirements_path = PROJECT_ROOT / "requirements.txt"
if requirements_path.exists():
    print("requirements.txt found.")
# Out:
# Base dependencies available.
# Optional dependencies available.
# requirements.txt found.

# %% [markdown]
# ## Read and Validate Configuration
#
# The notebook validates only whether required values exist. It does not print usernames, passwords, DSNs, schema names, database versions, or local paths.
#
# This Antigravity version accepts both naming styles:
#
# | Antigravity variable | FreeSQL-style alias |
# |---|---|
# | `ORACLE_USER` | `DB_USER` |
# | `ORACLE_PASSWORD` | `DB_PASSWORD` |
# | `ORACLE_DSN` | `DB_CONNECT_STRING` or `DB_DSN` |
#
# It also validates the SQLcl/MCP settings used later by Antigravity.

# %%
import os
import platform
from pathlib import Path
from dotenv import load_dotenv
import pandas as pd
import matplotlib.pyplot as plt


def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / ".env").exists() and (candidate / "requirements.txt").exists():
            return candidate
    return start


PROJECT_ROOT = find_project_root(Path.cwd())
NOTEBOOK_DIR = PROJECT_ROOT / "notebooks"
ENV_PATH = PROJECT_ROOT / ".env"

load_dotenv(ENV_PATH, override=True)
print("Loaded .env")

oracle_user = (os.getenv("ORACLE_USER") or os.getenv("DB_USER") or "").strip()
oracle_password = os.getenv("ORACLE_PASSWORD") or os.getenv("DB_PASSWORD") or ""
oracle_dsn = (os.getenv("ORACLE_DSN") or os.getenv("DB_CONNECT_STRING") or os.getenv("DB_DSN") or "").strip()

CONFIG = {
    "ORACLE_USER": oracle_user,
    "ORACLE_PASSWORD": oracle_password,
    "ORACLE_DSN": oracle_dsn,
    "SQLCL_PATH": os.getenv("SQLCL_PATH", "").strip(),
    "SQLCL_CONNECTION_NAME": os.getenv("ANTIGRAVITY_SQLCL_CONNECTION_NAME", os.getenv("SQLCL_CONNECTION_NAME", "antigravity_mcp")).strip() or "antigravity_mcp",
    "ANTIGRAVITY_MCP_CONFIG_PATH": os.getenv("ANTIGRAVITY_MCP_CONFIG_PATH", "").strip(),
    "TNS_ADMIN": os.getenv("TNS_ADMIN", "").strip(),
    "OPENAI_API_KEY": os.getenv("OPENAI_API_KEY", "").strip(),
}

config_readiness = pd.DataFrame([
    {"setting": "FreeSQL / Oracle AI Database credentials", "status": "READY" if CONFIG["ORACLE_USER"] and CONFIG["ORACLE_PASSWORD"] and CONFIG["ORACLE_DSN"] else "ACTION_NEEDED", "public_value": "<loaded from .env>"},
    {"setting": "SQLcl executable", "status": "CONFIGURED" if CONFIG["SQLCL_PATH"] else "AUTO_DETECT", "public_value": "<SQLCL_PATH set>" if CONFIG["SQLCL_PATH"] else "<search PATH>"},
    {"setting": "SQLcl saved connection alias", "status": "READY", "public_value": CONFIG["SQLCL_CONNECTION_NAME"]},
    {"setting": "Antigravity MCP config path", "status": "DEFAULT" if not CONFIG["ANTIGRAVITY_MCP_CONFIG_PATH"] else "CONFIGURED", "public_value": "<default ~/.gemini/config/mcp_config.json>" if not CONFIG["ANTIGRAVITY_MCP_CONFIG_PATH"] else "<custom path set>"},
    {"setting": "TNS_ADMIN", "status": "OPTIONAL" if not CONFIG["TNS_ADMIN"] else "CONFIGURED", "public_value": "<not set>" if not CONFIG["TNS_ADMIN"] else "<configured>"},
    {"setting": "OpenAI API key", "status": "OPTIONAL" if not CONFIG["OPENAI_API_KEY"] else "CONFIGURED", "public_value": "<not required for local demo>" if not CONFIG["OPENAI_API_KEY"] else "<loaded from .env>"},
])

print("Configuration readiness matrix")
display(config_readiness)
# Out:
# Loaded .env
# Configuration readiness matrix
#                                     setting      status  \
# 0  FreeSQL / Oracle AI Database credentials       READY
# 1                          SQLcl executable  CONFIGURED
# 2              SQLcl saved connection alias       READY
# 3               Antigravity MCP config path     DEFAULT
# 4                                 TNS_ADMIN  CONFIGURED
# 5                            OpenAI API key    OPTIONAL
#
#                                  public_value
# 0                          <loaded from .env>
# 1                            <SQLCL_PATH set>
# 2                             antigravity_mcp
# 3  <default ~/.gemini/config/mcp_config.json>
# 4                                <configured>
# 5               <not required for local demo>

# %% [markdown]
# ## Step 1 - Create and Verify the Oracle Database Connection
#
# This cell creates the Oracle Database connection pool used by the notebook. When the connection string points to FreeSQL, it also verifies the FreeSQL setup requested for this content.
#
# A pool is used instead of a single raw connection because Oracle AI Agent Memory can perform several kinds of database work during a realistic application flow: message writes, memory extraction, memory inspection, and retrieval. Even in a notebook, using a pool mirrors the application pattern more closely.
#
# The check intentionally prints only readiness status. It does not display usernames, schema names, DSNs, passwords, database versions, or local paths.
#
# It checks that:
#
# - Python can connect to the configured Oracle Database service;
# - a simple `SELECT 1 FROM dual` query succeeds;
# - the schema can create, insert into, read from, and drop a small table.
#
# The table-permission check matters because Oracle AI Agent Memory creates and manages its own database objects during schema setup.
#
# The connection also sets a Developer Hub program identifier before the pool is created, so usage can be recognized in Oracle Developer Hub telemetry.

# %%
import oracledb
from uuid import uuid4

oracledb.defaults.program = "devrel-developerhub-antigravity-mcp-freesql-preflight"

required = ["ORACLE_USER", "ORACLE_PASSWORD", "ORACLE_DSN"]
missing = [key for key in required if not CONFIG[key]]
if missing:
    raise RuntimeError(f"Missing required FreeSQL connection settings in .env: {missing}")

preflight_pool = oracledb.create_pool(
    user=CONFIG["ORACLE_USER"],
    password=CONFIG["ORACLE_PASSWORD"],
    dsn=CONFIG["ORACLE_DSN"],
    min=1,
    max=2,
    increment=1,
)

permission_check_table = f"AG_FREESQL_CHECK_{uuid4().hex[:8].upper()}"

try:
    with preflight_pool.acquire() as preflight_connection:
        with preflight_connection.cursor() as preflight_cursor:
            preflight_cursor.execute("SELECT 1 FROM dual").fetchone()
            preflight_cursor.execute(
                f"""
                CREATE TABLE {permission_check_table} (
                    id NUMBER PRIMARY KEY,
                    note VARCHAR2(100)
                )
                """
            )
            preflight_cursor.execute(
                f"INSERT INTO {permission_check_table} (id, note) VALUES (:id, :note)",
                id=1,
                note="table permission check",
            )
            count = preflight_cursor.execute(
                f"SELECT COUNT(*) FROM {permission_check_table}"
            ).fetchone()[0]
            if count != 1:
                raise RuntimeError("Table permission check returned an unexpected row count.")
        preflight_connection.commit()
finally:
    try:
        with preflight_pool.acquire() as cleanup_connection:
            with cleanup_connection.cursor() as cleanup_cursor:
                cleanup_cursor.execute(f"DROP TABLE {permission_check_table} PURGE")
            cleanup_connection.commit()
    except oracledb.Error:
        pass
    preflight_pool.close()

print("FreeSQL connection and table permissions: READY")
# Out:
# FreeSQL connection and table permissions: READY

# %% [markdown]
# ## Step 2 - Validate the SQLcl MCP Environment
#
# Antigravity CLI starts SQLcl as an MCP server by launching `sql -mcp`. This cell does **not** start the MCP server, because an MCP server is a long-running process. Instead, it checks whether SQLcl and Java are discoverable and captures their readiness.
#
# If the SQLcl row says `ACTION_NEEDED`, that does not mean the Oracle AI Database memory workflow failed. It means live Antigravity MCP validation still needs standalone SQLcl configured through `SQLCL_PATH`.
#
# If SQLcl is not on `PATH`, set `SQLCL_PATH` in `.env` to the full path of standalone SQLcl, for example:
#
# ```env
# SQLCL_PATH=C:\tools\sqlcl\bin\sql.exe
# ```

# %%
import shutil
import subprocess
from pathlib import Path


def run_process(command, timeout=15, input_text=None):
    try:
        completed = subprocess.run(
            command,
            capture_output=True,
            text=True,
            timeout=timeout,
            shell=False,
            input=input_text,
        )
        output = (completed.stdout or "") + (completed.stderr or "")
        return {
            "ok": completed.returncode == 0,
            "returncode": completed.returncode,
            "output": output.strip(),
            "error": None,
        }
    except Exception as exc:
        return {
            "ok": False,
            "returncode": None,
            "output": "",
            "error": str(exc),
        }


def resolve_sqlcl(sqlcl_path: str):
    if sqlcl_path:
        candidate = Path(sqlcl_path)
        if candidate.exists():
            return str(candidate)
        return sqlcl_path
    return shutil.which("sqlcl") or shutil.which("sqlcl.exe") or shutil.which("sql") or shutil.which("sql.exe")


def looks_like_usable_sqlcl(check: dict) -> bool:
    output = (check.get("output") or "") + (check.get("error") or "")
    if not check.get("ok"):
        return False
    return "SQLcl" in output or "Oracle SQLDeveloper Command-Line" in output


def summarize_sqlcl_issue(check: dict) -> str:
    detail = (check.get("output") or check.get("error") or "").lower()
    if "noclassdeffounderror" in detail or "unable to initialize main class" in detail:
        return "Detected a sql executable that is not a standalone SQLcl MCP runtime. Set SQLCL_PATH to standalone SQLcl."
    if "not found" in detail or not SQLCL_EXECUTABLE:
        return "SQLcl was not found. Install standalone SQLcl 25.2+ and set SQLCL_PATH."
    if not check.get("ok"):
        return "SQLcl version check failed. Validate SQLcl installation and Java runtime."
    return "SQLcl version output did not match the expected SQLcl signature."


SQLCL_EXECUTABLE = resolve_sqlcl(CONFIG["SQLCL_PATH"])
sqlcl_check = run_process([SQLCL_EXECUTABLE, "-version"]) if SQLCL_EXECUTABLE else {
    "ok": False,
    "returncode": None,
    "output": "",
    "error": "SQLcl executable was not found. Set SQLCL_PATH or add SQLcl to PATH.",
}
SQLCL_MCP_READY = looks_like_usable_sqlcl(sqlcl_check)
java_check = run_process(["java", "-version"])

java_first_line = (java_check["output"] or "").splitlines()[0] if java_check["ok"] and java_check["output"] else "Java runtime was not validated."

mcp_runtime_report = pd.DataFrame([
    {
        "check": "Standalone SQLcl for MCP",
        "status": "READY" if SQLCL_MCP_READY else "ACTION_NEEDED",
        "evidence": "SQLcl version validated." if SQLCL_MCP_READY else summarize_sqlcl_issue(sqlcl_check),
        "next_step": "Use this executable in Antigravity MCP config." if SQLCL_MCP_READY else "Install standalone SQLcl 25.2+ and set SQLCL_PATH.",
    },
    {
        "check": "Java runtime",
        "status": "READY" if java_check["ok"] else "ACTION_NEEDED",
        "evidence": java_first_line,
        "next_step": "No action." if java_check["ok"] else "Install Oracle JRE 17 or 21.",
    },
    {
        "check": "MCP launch mode",
        "status": "READY" if SQLCL_MCP_READY else "PENDING",
        "evidence": "`sql -mcp` will be used by Antigravity CLI.",
        "next_step": "Restart Antigravity CLI or open a new terminal session after config change." if SQLCL_MCP_READY else "Complete SQLcl validation first.",
    },
])

display(mcp_runtime_report)
# Out:
#                       check status  \
# 0  Standalone SQLcl for MCP  READY
# 1              Java runtime  READY
# 2           MCP launch mode  READY
#
#                                       evidence  \
# 0                     SQLcl version validated.
# 1          openjdk version "26.0.1" 2026-04-21
# 2  `sql -mcp` will be used by Antigravity CLI.
#
#                                            next_step
# 0     Use this executable in Antigravity MCP config.
# 1                                         No action.
# 2  Restart Antigravity CLI or open a new terminal...

# %% [markdown]
# ## Step 3 - Generate an Antigravity MCP Config Preview
#
# Antigravity stores custom MCP server configuration in `mcp_config.json`. Use `.agents/mcp_config.json` for a workspace-scoped configuration or `~/.gemini/config/mcp_config.json` for a global configuration.
#
# For SQLcl MCP, the server definition is a local stdio command:
#
# ```json
# {
#   "mcpServers": {
#     "sqlcl": {
#       "command": "/absolute/path/to/sql",
#       "args": ["-mcp"]
#     }
#   }
# }
# ```
#
# The `command` should point to the standalone SQLcl executable. The notebook uses `SQLCL_PATH` if provided, otherwise it tries to discover `sql` from `PATH`.
#
# This notebook writes a **preview** file into the project folder. It does not overwrite your real Antigravity MCP config. That keeps the workflow safe and reviewable.

# %%
from pathlib import Path
import json


def default_antigravity_mcp_config_path() -> Path:
    return Path.home() / ".gemini" / "config" / "mcp_config.json"


command_for_config = SQLCL_EXECUTABLE if SQLCL_MCP_READY else (CONFIG["SQLCL_PATH"] or "PATH_TO_STANDALONE_SQLCL_BIN_SQL_EXE")

server_config = {
    "command": command_for_config,
    "args": ["-mcp"],
}
if CONFIG["TNS_ADMIN"]:
    server_config["env"] = {"TNS_ADMIN": CONFIG["TNS_ADMIN"]}

mcp_config_json = {
    "mcpServers": {
        "sqlcl": server_config
    }
}

preview_path = PROJECT_ROOT / "antigravity_sqlcl_mcp_config.preview.json"
preview_path.write_text(json.dumps(mcp_config_json, indent=2) + "\n", encoding="utf-8")

safe_mcp_config_json = json.loads(json.dumps(mcp_config_json))
if command_for_config != "PATH_TO_STANDALONE_SQLCL_BIN_SQL_EXE":
    safe_mcp_config_json["mcpServers"]["sqlcl"]["command"] = "<STANDALONE_SQLCL_EXECUTABLE>"

config_artifact = {
    "artifact": "Antigravity MCP server config preview",
    "server_name": "sqlcl",
    "launch_command": "sql -mcp",
    "preview_file": "antigravity_sqlcl_mcp_config.preview.json",
    "config_target": str(Path(CONFIG["ANTIGRAVITY_MCP_CONFIG_PATH"]) if CONFIG["ANTIGRAVITY_MCP_CONFIG_PATH"] else default_antigravity_mcp_config_path()),
    "ready_for_copy": bool(SQLCL_MCP_READY),
}

print("\nSanitized MCP server JSON:")
print(json.dumps(safe_mcp_config_json, indent=2))
# Out:
# Sanitized MCP server JSON:
# {
#   "mcpServers": {
#     "sqlcl": {
#       "command": "<STANDALONE_SQLCL_EXECUTABLE>",
#       "args": [
#         "-mcp"
#       ],
#       "env": {
#         "TNS_ADMIN": "/Users/srinidhi/Downloads/Local notebook/tns"
#       }
#     }
#   }
# }

# %% [markdown]
# ## Step 4 - Saved SQLcl Connection Check
#
# SQLcl MCP uses SQLcl's connection store instead of inventing database connections dynamically. For an MCP-compatible connection, save the connection and persist the password with `-savepwd`.
#
# This cell prints a safe template and validates the configured saved connection alias by launching SQLcl with `-name <alias>`. That is the same saved-connection path Antigravity CLI relies on when SQLcl MCP starts locally. The cell does not print your real password.

# %%
from pathlib import Path

connection_name = CONFIG["SQLCL_CONNECTION_NAME"]
expected_user = CONFIG["ORACLE_USER"].upper()


def show_dataframe(df):
    """Display a DataFrame even when the later notebook helper has not been run yet."""
    if "display_df" in globals():
        display_df(df)
    else:
        display(df)


def compact_process_lines(process_result):
    output = (process_result.get("output") or "") + (process_result.get("error") or "")
    return [line.strip() for line in output.splitlines() if line.strip()]


connection_contract = {
    "connection_alias": connection_name,
    "connection_store": "~/.dbtools",
    "password_requirement_for_mcp": "Use -savepwd for MCP-compatible saved connections.",
    "recommended_role": "read-only validation role first; expand scopes only after review.",
}

print("SQLcl saved connection contract:")
print(json.dumps(connection_contract, indent=2))
print("\nTemplate to run in SQLcl after confirming credentials:")
print(f"conn -save {connection_name} -savepwd <ORACLE_USER>/<ORACLE_PASSWORD>@<ORACLE_DSN>")

sqlcl_alias_connect_ready = False
sqlcl_alias_registered = False
direct_db_ready = False
direct_db_user = None

if SQLCL_MCP_READY:
    sqlcl_connection_check = run_process(
        [SQLCL_EXECUTABLE, "-s", "-name", connection_name],
        timeout=25,
        input_text="SELECT USER FROM dual;\nexit\n",
    )
    sqlcl_connection_output = (sqlcl_connection_check.get("output") or "") + (sqlcl_connection_check.get("error") or "")
    sqlcl_alias_connect_ready = sqlcl_connection_check["ok"] and expected_user in sqlcl_connection_output.upper()

    sqlcl_alias_show_check = run_process(
        [SQLCL_EXECUTABLE, "-s", "/nolog"],
        timeout=25,
        input_text=f"connmgr show {connection_name}\nexit\n",
    )
    sqlcl_alias_show_output = (sqlcl_alias_show_check.get("output") or "") + (sqlcl_alias_show_check.get("error") or "")
    sqlcl_alias_registered = (
        sqlcl_alias_show_check["ok"]
        and f"NAME: {connection_name.upper()}" in sqlcl_alias_show_output.upper()
        and f"USER: {CONFIG['ORACLE_USER'].upper()}" in sqlcl_alias_show_output.upper()
    )
else:
    sqlcl_connection_check = {
        "ok": False,
        "returncode": None,
        "output": "",
        "error": "SQLcl runtime is not ready, so the saved connection alias was not tested.",
    }
    sqlcl_connection_output = sqlcl_connection_check["error"]
    sqlcl_alias_show_check = sqlcl_connection_check
    sqlcl_alias_show_output = sqlcl_connection_output

try:
    import oracledb

    direct_connection = oracledb.connect(
        user=CONFIG["ORACLE_USER"],
        password=CONFIG["ORACLE_PASSWORD"],
        dsn=CONFIG["ORACLE_DSN"],
    )
    direct_cursor = direct_connection.cursor()
    direct_db_user = direct_cursor.execute("SELECT USER FROM dual").fetchone()[0]
    direct_db_ready = direct_db_user.upper() == expected_user
    direct_connection.close()
except Exception as exc:
    direct_db_error = str(exc)
else:
    direct_db_error = ""

SQLCL_CONNECTION_READY = sqlcl_alias_connect_ready or (sqlcl_alias_registered and direct_db_ready)
SQLCL_CONNECTION_VALIDATION_PATH = (
    "SQLcl -name"
    if sqlcl_alias_connect_ready
    else "connmgr show + direct database identity"
    if SQLCL_CONNECTION_READY
    else "not validated"
)

if sqlcl_alias_connect_ready:
    sqlcl_connection_detail = "SQLcl saved alias connected successfully."
    sqlcl_connection_evidence = "Saved alias connected as the configured .env database user."
    sqlcl_connection_next_step = "No action."
elif sqlcl_alias_registered and direct_db_ready:
    sqlcl_connection_detail = "Saved alias is registered and the configured database identity is valid."
    sqlcl_connection_evidence = f"Alias {connection_name} is registered and the direct database identity check succeeded."
    sqlcl_connection_next_step = "No action."
else:
    connection_lines = compact_process_lines(sqlcl_connection_check)
    show_lines = compact_process_lines(sqlcl_alias_show_check)
    fallback_detail = direct_db_error or (show_lines[-1] if show_lines else "")
    sqlcl_connection_detail = "Saved alias did not validate through SQLcl or the direct database fallback."
    sqlcl_connection_evidence = (
        connection_lines[-1]
        if connection_lines
        else fallback_detail
        if fallback_detail
        else "No SQLcl connection output was returned."
    )
    sqlcl_connection_next_step = "Run the template above with -savepwd, then rerun this cell."

connection_validation = pd.DataFrame([
    {
        "check": "Saved SQLcl connection alias",
        "value": connection_name,
        "status": "READY" if SQLCL_CONNECTION_READY else "ACTION_NEEDED",
        "validation_path": SQLCL_CONNECTION_VALIDATION_PATH,
        "detail": sqlcl_connection_detail,
        "evidence": sqlcl_connection_evidence,
        "next_step": sqlcl_connection_next_step,
    }
])

show_dataframe(connection_validation)
# Out:
# SQLcl saved connection contract:
# {
#   "connection_alias": "antigravity_mcp",
#   "connection_store": "~/.dbtools",
#   "password_requirement_for_mcp": "Use -savepwd for MCP-compatible saved connections.",
#   "recommended_role": "read-only validation role first; expand scopes only after review."
# }
#
# Template to run in SQLcl after confirming credentials:
# conn -save antigravity_mcp -savepwd <ORACLE_USER>/<ORACLE_PASSWORD>@<ORACLE_DSN>
#                           check            value status validation_path  \
# 0  Saved SQLcl connection alias  antigravity_mcp  READY     SQLcl -name
#
#                                       detail  \
# 0  SQLcl saved alias connected successfully.
#
#                                             evidence   next_step
# 0  Saved alias connected as the configured .env d...  No action.

# %% [markdown]
# ## Step 5 - Manual Check: Validate SQLcl MCP in Antigravity
#
# This notebook cannot drive your Antigravity session from inside Jupyter, so this section is intentionally a handoff from validated notebook state to live MCP usage.
#
# 1. Review `antigravity_sqlcl_mcp_config.preview.json`.
# 2. Copy the `mcpServers.sqlcl` block into `.agents/mcp_config.json` for this workspace or `~/.gemini/config/mcp_config.json` globally.
# 3. Restart Antigravity or reload MCP servers from the `/mcp` manager.
# 4. Open Antigravity's MCP manager with `/mcp` and confirm the SQLcl server is listed.
# 5. Ask a read-only question first, such as:
#
# ```text
# Using the SQLcl MCP server, list the available Oracle connections and run SELECT USER FROM dual. Do not run DDL or DML.
# ```
#
# Expected result: Antigravity discovers SQLcl MCP tools, SQLcl uses saved connection profiles, and Oracle AI Database privileges decide what can be read or changed.

# %% [markdown]
# ## Step 6 - Connect to Oracle AI Database from Python
#
# The MCP loop is operational: Antigravity CLI calls SQLcl tools. The notebook loop is persistence-oriented: Python creates and queries the Oracle memory substrate.
#
# This connection is used to create the demo memory tables and retrieval workflow.

# %%
import oracledb

oracledb.defaults.program = "devrel-developerhub-antigravity-mcp-oracle-ai-database"

required = ["ORACLE_USER", "ORACLE_PASSWORD", "ORACLE_DSN"]
missing = [key for key in required if not CONFIG[key]]
if missing:
    raise RuntimeError(f"Missing required Oracle settings in .env: {missing}")

connection = oracledb.connect(
    user=CONFIG["ORACLE_USER"],
    password=CONFIG["ORACLE_PASSWORD"],
    dsn=CONFIG["ORACLE_DSN"],
)
connection.autocommit = False
cursor = connection.cursor()

db_version = connection.version
current_user = cursor.execute("SELECT USER FROM dual").fetchone()[0]

print("Connected to Oracle AI Database successfully.")
# Out:
# Connected to Oracle AI Database successfully.

# %% [markdown]
# ## Helper Utilities
#
# These helpers keep the notebook readable and safe to rerun.

# %%
import re
import json
import pandas as pd
from typing import Any


def lob_to_text(value: Any) -> Any:
    if hasattr(value, "read"):
        return value.read()
    return value


def rows_to_dataframe(cursor_obj, rows):
    columns = [col[0].lower() for col in cursor_obj.description] if cursor_obj.description else []
    normalized_rows = [
        [lob_to_text(value) for value in row]
        for row in rows
    ]
    return pd.DataFrame(normalized_rows, columns=columns)


def run_sql(sql: str, params: dict | None = None, fetch: bool = True, commit: bool = False) -> pd.DataFrame | None:
    cursor.execute(sql, params or {})
    if commit:
        connection.commit()
    if fetch and cursor.description:
        return rows_to_dataframe(cursor, cursor.fetchall())
    return None


def is_safe_name(name: str) -> bool:
    return bool(re.fullmatch(r"[A-Za-z][A-Za-z0-9_]{0,127}", name))


def execute_ddl(sql: str):
    cursor.execute(sql)
    connection.commit()


def safe_drop_table(table_name: str, verbose: bool = False):
    if not is_safe_name(table_name):
        raise ValueError(f"Unsafe table name: {table_name}")
    try:
        execute_ddl(f"DROP TABLE {table_name} PURGE")
        if verbose:
            print(f"Dropped table: {table_name}")
    except oracledb.DatabaseError as exc:
        error_obj = exc.args[0]
        if getattr(error_obj, "code", None) == 942:
            if verbose:
                print(f"Table did not exist: {table_name}")
        else:
            raise


def safe_drop_index(index_name: str, verbose: bool = False):
    if not is_safe_name(index_name):
        raise ValueError(f"Unsafe index name: {index_name}")
    try:
        execute_ddl(f"DROP INDEX {index_name}")
        if verbose:
            print(f"Dropped index: {index_name}")
    except oracledb.DatabaseError as exc:
        error_obj = exc.args[0]
        if getattr(error_obj, "code", None) in [1418, 942]:
            if verbose:
                print(f"Index did not exist: {index_name}")
        else:
            raise


def display_df(df: pd.DataFrame, empty_message: str = "No rows returned.", max_rows: int = 6):
    if df is None or df.empty:
        print(empty_message)
    else:
        display(df.head(max_rows))



def plot_bar(df: pd.DataFrame, x: str, y: str, title: str, color: str = "#2f6f73"):
    if df is None or df.empty:
        print(f"No data to plot for: {title}")
        return
    ax = df.plot(kind="barh", x=x, y=y, legend=False, figsize=(8, max(3, len(df) * 0.45)), color=color)
    ax.set_title(title)
    ax.set_xlabel(y)
    ax.set_ylabel("")
    ax.invert_yaxis()
    for container in ax.containers:
        ax.bar_label(container, fmt="%.2f", padding=3)
    plt.tight_layout()
    plt.show()


def plot_mcp_policy_heatmap(df: pd.DataFrame):
    if df is None or df.empty:
        print("No MCP policy data to plot.")
        return
    decision_weight = {
        "ALLOW": 1,
        "REQUIRE_CONFIRMATION": 2,
        "BLOCK_IN_READONLY_MODE": 3,
    }
    risk_weight = {"LOW": 1, "LOW_TO_MEDIUM": 2, "HIGH": 3, "CRITICAL": 4, "UNKNOWN": 4}
    matrix = df[["tool_name", "risk", "decision"]].copy()
    matrix["risk_weight"] = matrix["risk"].map(risk_weight).fillna(4)
    matrix["decision_weight"] = matrix["decision"].map(decision_weight).fillna(3)
    plot_values = matrix[["risk_weight", "decision_weight"]].to_numpy()

    fig, ax = plt.subplots(figsize=(8, max(3, len(matrix) * 0.55)))
    image = ax.imshow(plot_values, cmap="YlOrRd", aspect="auto", vmin=1, vmax=4)
    ax.set_xticks([0, 1])
    ax.set_xticklabels(["risk", "decision"])
    ax.set_yticks(range(len(matrix)))
    ax.set_yticklabels(matrix["tool_name"])
    ax.set_title("MCP tool contract heatmap")

    for row in range(plot_values.shape[0]):
        ax.text(0, row, matrix.iloc[row]["risk"], ha="center", va="center", fontsize=8)
        ax.text(1, row, matrix.iloc[row]["decision"], ha="center", va="center", fontsize=8)

    fig.colorbar(image, ax=ax, fraction=0.03, pad=0.04)
    plt.tight_layout()
    plt.show()


def plot_vector_lollipop(df: pd.DataFrame):
    if df is None or df.empty:
        print("No vector search data to plot.")
        return
    plot_df = df.sort_values("vector_score", ascending=True).copy()
    y_positions = range(len(plot_df))
    fig, ax = plt.subplots(figsize=(8, max(3, len(plot_df) * 0.5)))
    ax.hlines(y=y_positions, xmin=0, xmax=plot_df["vector_score"], color="#9fb7c9", linewidth=2)
    ax.scatter(plot_df["vector_score"], y_positions, color="#2d5f8b", s=90)
    ax.set_yticks(list(y_positions))
    ax.set_yticklabels(plot_df["title"])
    ax.set_xlim(0, max(1.0, float(plot_df["vector_score"].max()) + 0.05))
    ax.set_xlabel("vector_score")
    ax.set_title("Vector search score distribution")
    for y, score in zip(y_positions, plot_df["vector_score"]):
        ax.text(score + 0.02, y, f"{score:.2f}", va="center")
    plt.tight_layout()
    plt.show()


def plot_hybrid_signal_mix(query: str, tenant_id: str = "TENANT_A", top_k: int = 5):
    lexical = lexical_search(query, tenant_id=tenant_id, top_k=top_k).copy()
    semantic = vector_search(query, tenant_id=tenant_id, top_k=top_k).copy()
    if lexical.empty or semantic.empty:
        print("Not enough data to plot hybrid signal mix.")
        return

    lexical["lexical_norm"] = normalize_series(lexical["lexical_score"].astype(float))
    semantic["vector_norm"] = normalize_series(semantic["vector_score"].astype(float))
    merged = pd.merge(
        lexical[["chunk_id", "title", "lexical_norm"]],
        semantic[["chunk_id", "vector_norm"]],
        on="chunk_id",
        how="outer",
    ).fillna(0)
    merged["combined"] = merged["lexical_norm"] + merged["vector_norm"]
    merged = merged.sort_values("combined", ascending=True).tail(top_k)

    plot_df = merged.reset_index(drop=True).copy()
    plot_df["lexical_norm"] = pd.to_numeric(plot_df["lexical_norm"], errors="coerce").fillna(0.0)
    plot_df["vector_norm"] = pd.to_numeric(plot_df["vector_norm"], errors="coerce").fillna(0.0)
    y_positions = list(range(len(plot_df)))

    fig, ax = plt.subplots(figsize=(8, max(3, len(plot_df) * 0.5)))
    ax.barh(y_positions, plot_df["lexical_norm"].to_numpy(dtype=float), label="lexical", color="#c27c4b")
    ax.barh(
        y_positions,
        plot_df["vector_norm"].to_numpy(dtype=float),
        left=plot_df["lexical_norm"].to_numpy(dtype=float),
        label="vector",
        color="#4f7f9f",
    )
    ax.set_yticks(y_positions)
    ax.set_yticklabels(plot_df["title"].astype(str))
    ax.set_title("Hybrid retrieval signal mix")
    ax.set_xlabel("normalized contribution")
    ax.legend(loc="lower right")
    plt.tight_layout()
    plt.show()


def plot_evidence_radar(df: pd.DataFrame, title: str = "Evidence profile"):
    if df is None or df.empty:
        print("No evidence data to plot.")
        return
    category_scores = df.groupby("category")["hybrid_score"].max().sort_values(ascending=False)
    labels = list(category_scores.index)
    values = category_scores.to_numpy(dtype=float)
    values = values / values.max() if values.max() else values

    angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False)
    values_closed = np.concatenate([values, values[:1]])
    angles_closed = np.concatenate([angles, angles[:1]])

    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, polar=True)
    ax.plot(angles_closed, values_closed, color="#6f5f90", linewidth=2)
    ax.fill(angles_closed, values_closed, color="#6f5f90", alpha=0.20)
    ax.set_xticks(angles)
    ax.set_xticklabels(labels)
    ax.set_yticklabels([])
    ax.set_title(title)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Step 7 - Define MCP Tool Policy
#
# The most important technical point in this notebook is that MCP should make tool access explicit. Antigravity should not behave as if it has invisible database access. Each operation should be represented as a tool call with a known boundary.
#
# This cell creates a simple policy gate that classifies tool calls before execution:
#
# - discovery calls are allowed,
# - bounded read-only SQL is allowed,
# - write-like requests require confirmation,
# - destructive requests are blocked in read-only mode,
# - memory retrieval remains tenant-scoped.
#
# Oracle AI Database privileges are still the real enforcement layer. The policy gate is here to make the notebook's MCP behavior visible before any live tool execution happens.

# %%
MCP_TOOL_POLICY = {
    "list-connections": {
        "readOnlyHint": True,
        "destructiveHint": False,
        "requiresConfirmation": False,
        "risk": "LOW",
        "purpose": "Discover saved SQLcl connection aliases.",
    },
    "connect": {
        "readOnlyHint": True,
        "destructiveHint": False,
        "requiresConfirmation": False,
        "risk": "LOW_TO_MEDIUM",
        "purpose": "Select a saved SQLcl connection alias such as antigravity_mcp.",
    },
    "run-sql": {
        "readOnlyHint": True,
        "destructiveHint": False,
        "requiresConfirmation": False,
        "risk": "LOW_TO_MEDIUM",
        "purpose": "Run SQL through SQLcl MCP. The SQL text classifier below still gates write-like or destructive statements.",
    },
    "run-sqlcl": {
        "readOnlyHint": False,
        "destructiveHint": True,
        "requiresConfirmation": True,
        "risk": "CRITICAL",
        "purpose": "DDL operations require explicit approval and elevated privileges.",
    },
    "oracle_memory/retrieve": {
        "readOnlyHint": True,
        "destructiveHint": False,
        "requiresConfirmation": False,
        "risk": "LOW",
        "purpose": "Retrieve tenant-scoped Oracle AI Database memory.",
    },
}


def classify_mcp_tool_call(tool_name: str, sql_summary: str = "") -> dict:
    policy = MCP_TOOL_POLICY.get(tool_name, {
        "readOnlyHint": False,
        "destructiveHint": True,
        "requiresConfirmation": True,
        "risk": "UNKNOWN",
        "purpose": "Unknown tool; require review before use.",
    })
    lowered = f" {sql_summary.lower()} "
    write_terms = [" insert ", " update ", " delete ", " merge "]
    destructive_terms = [" drop ", " truncate ", " alter ", " grant ", " revoke "]
    write_detected = any(term in lowered for term in write_terms)
    destructive_detected = any(term in lowered for term in destructive_terms)

    decision = "ALLOW"
    reason = "Read-only or discovery operation."
    if policy["requiresConfirmation"] or write_detected:
        decision = "REQUIRE_CONFIRMATION"
        reason = "Write-capable operation detected."
    if policy["destructiveHint"] or destructive_detected:
        decision = "BLOCK_IN_READONLY_MODE"
        reason = "Destructive or DDL-like operation detected."

    return {
        "tool_name": tool_name,
        "risk": policy["risk"],
        "decision": decision,
        "read_only": policy["readOnlyHint"],
        "confirmation_required": policy["requiresConfirmation"] or write_detected or destructive_detected,
        "control_status": "SAFE" if decision == "ALLOW" else "CONTROLLED",
        "reason": reason,
    }


policy_examples = pd.DataFrame([
    classify_mcp_tool_call("list-connections"),
    classify_mcp_tool_call("connect", "connect to saved alias antigravity_mcp"),
    classify_mcp_tool_call("run-sql", "select owner, table_name from all_tables fetch first 10 rows only"),
    classify_mcp_tool_call("run-sql", "update support_jobs set reviewed = 'Y'"),
    classify_mcp_tool_call("run-sqlcl", "drop table old_memory"),
    classify_mcp_tool_call("oracle_memory/retrieve", "retrieve tenant scoped MCP setup memory"),
])

print("MCP tool contract gate:")
display_df(policy_examples)

plot_mcp_policy_heatmap(policy_examples)
# Out:
# MCP tool contract gate:
#                 tool_name           risk                decision  read_only  \
# 0        list-connections            LOW                   ALLOW       True
# 1                 connect  LOW_TO_MEDIUM                   ALLOW       True
# 2                 run-sql  LOW_TO_MEDIUM                   ALLOW       True
# 3                 run-sql  LOW_TO_MEDIUM    REQUIRE_CONFIRMATION       True
# 4               run-sqlcl       CRITICAL  BLOCK_IN_READONLY_MODE      False
# 5  oracle_memory/retrieve            LOW                   ALLOW       True
#
#    confirmation_required control_status  \
# 0                  False           SAFE
# 1                  False           SAFE
# 2                  False           SAFE
# 3                   True     CONTROLLED
# 4                   True     CONTROLLED
# 5                  False           SAFE
#
#                                         reason
# 0            Read-only or discovery operation.
# ...

# %% [markdown]
# **DEVELOPER PATTERN: MCP tool gate**
#
# Use this when: You want to inspect or log what tool class a request falls into before execution.
#
# Minimal call: `classify_mcp_tool_call("run-sql", "select ...")`
#
# Expected output: dict with `risk`, `decision`, `confirmation_required`
#
# Adapt for your app: Extend `MCP_TOOL_POLICY` with your own tool names and risk levels. These examples use SQLcl MCP tool names such as `list-connections`, `connect`, `run-sql`, and `run-sqlcl`.
#
# Production note: This gate is observability, not enforcement. Real enforcement stays in Oracle privileges.

# %% [markdown]
# ## Step 8 - Create Oracle AI Database-Backed Memory Tables
#
# The companion article, *Build a Controlled Antigravity MCP Workflow with Oracle AI Database*, separates memory into three practical categories:
# - **Conversational memory**: user and assistant turns.
# - **Operational memory**: MCP tool calls, inputs, outputs, status, and errors.
# - **Semantic memory**: reusable knowledge chunks and embeddings.
#
# The table names are prefixed with `ANTIGRAVITY_` so the demo is easy to identify and clean up.

# %%
RESET_DEMO = True

TABLES = [
    "ANTIGRAVITY_VALIDATION_CHECKS",
    "ANTIGRAVITY_KB_CHUNKS",
    "ANTIGRAVITY_TOOL_LOGS",
    "ANTIGRAVITY_CONVERSATIONAL_MEMORY",
]

DDL = {
    "antigravity_conversational_memory": """
        CREATE TABLE antigravity_conversational_memory (
            memory_id      NUMBER GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
            tenant_id      VARCHAR2(64) NOT NULL,
            thread_id      VARCHAR2(128) NOT NULL,
            role           VARCHAR2(32) NOT NULL,
            content        CLOB NOT NULL,
            metadata_json  CLOB CHECK (metadata_json IS JSON),
            event_seq      NUMBER NOT NULL,
            event_time     TIMESTAMP NOT NULL,
            created_at     TIMESTAMP DEFAULT SYSTIMESTAMP NOT NULL
        )
    """,
    "antigravity_tool_logs": """
        CREATE TABLE antigravity_tool_logs (
            log_id         NUMBER GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
            tenant_id      VARCHAR2(64) NOT NULL,
            thread_id      VARCHAR2(128) NOT NULL,
            tool_name      VARCHAR2(200) NOT NULL,
            tool_input     CLOB CHECK (tool_input IS JSON),
            tool_output    CLOB CHECK (tool_output IS JSON),
            status         VARCHAR2(32) NOT NULL,
            error_class    VARCHAR2(80),
            error_message  VARCHAR2(1000),
            event_seq      NUMBER NOT NULL,
            event_time     TIMESTAMP NOT NULL,
            created_at     TIMESTAMP DEFAULT SYSTIMESTAMP NOT NULL
        )
    """,
    "antigravity_kb_chunks": """
        CREATE TABLE antigravity_kb_chunks (
            chunk_id        NUMBER GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
            tenant_id       VARCHAR2(64) NOT NULL,
            source_name     VARCHAR2(200) NOT NULL,
            category        VARCHAR2(80) NOT NULL,
            title           VARCHAR2(300) NOT NULL,
            chunk_text      CLOB NOT NULL,
            metadata_json   CLOB CHECK (metadata_json IS JSON),
            embedding_json  CLOB CHECK (embedding_json IS JSON),
            created_at      TIMESTAMP DEFAULT SYSTIMESTAMP NOT NULL
        )
    """,
    "antigravity_validation_checks": """
        CREATE TABLE antigravity_validation_checks (
            check_id       NUMBER GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
            check_name     VARCHAR2(120) NOT NULL,
            status         VARCHAR2(32) NOT NULL,
            detail         VARCHAR2(1000),
            created_at     TIMESTAMP DEFAULT SYSTIMESTAMP NOT NULL
        )
    """,
}

if RESET_DEMO:
    safe_drop_index("ANTIGRAVITY_KB_TEXT_IDX")
    safe_drop_index("ANTIGRAVITY_KB_VECTOR_IDX")
    for table in TABLES:
        safe_drop_table(table)

for statement in DDL.values():
    execute_ddl(statement)

print("Oracle AI Database memory schema ready.")
# Out:
# Oracle AI Database memory schema ready.

# %% [markdown]
# ## Step 9 - Insert a Sample Antigravity + MCP Workflow
#
# These records are simulated teaching data. They show what an operational workflow should preserve, but they are not live SQLcl MCP telemetry captured from Antigravity CLI:
#
# - what the user asked,
# - what Antigravity planned,
# - what MCP tool calls were attempted,
# - which calls succeeded or failed,
# - and what memory should be available later.
#
# This is the key difference between assistant memory and system memory: the database gives us something queryable, auditable, and shareable across sessions.

# %%
SCENARIO = "support-job investigation"
BASE_EVENT_TIME = pd.Timestamp("2026-01-15 09:00:00")


def event_timestamp(step: int) -> str:
    return (BASE_EVENT_TIME + pd.Timedelta(seconds=step * 10)).strftime("%Y-%m-%d %H:%M:%S")


conversation_rows = [
    (1, "TENANT_A", "thread-antigravity-mcp-001", "user",
     "Can you inspect failed jobs from the Oracle support schema and summarize what changed since yesterday?",
     {"client": "Antigravity CLI", "loop": "operational", "memory_type": "conversation"}),
    (2, "TENANT_A", "thread-antigravity-mcp-001", "assistant",
     "I will use SQLcl MCP tools to list connections, run a bounded read-only query, and summarize with evidence.",
     {"client": "Antigravity CLI", "loop": "operational", "planned_boundary": "SQLcl MCP"}),
    (6, "TENANT_A", "thread-antigravity-mcp-001", "assistant",
     "The investigation found two failed jobs: one permission issue and one stale index maintenance job.",
     {"client": "Antigravity CLI", "loop": "grounded_response", "sources": ["antigravity_tool_logs"]}),
    (1, "TENANT_B", "thread-antigravity-mcp-002", "user",
     "Show the onboarding validation checklist for MCP connections.",
     {"client": "Antigravity CLI", "loop": "operational", "memory_type": "conversation"}),
]

tool_log_rows = [
    (3, "TENANT_A", "thread-antigravity-mcp-001", "list-connections",
     {"requested_by": "Antigravity CLI"},
     {"connections": [CONFIG["SQLCL_CONNECTION_NAME"]], "selected": CONFIG["SQLCL_CONNECTION_NAME"]},
     "SUCCESS", None, None),
    (4, "TENANT_A", "thread-antigravity-mcp-001", "run-sql",
     {"connection": CONFIG["SQLCL_CONNECTION_NAME"], "sql_summary": "select failed jobs with bounded result set"},
     {"rows": 2, "columns": ["job_name", "status", "error_code", "last_run"]},
     "SUCCESS", None, None),
    (5, "TENANT_A", "thread-antigravity-mcp-001", "run-sql",
     {"connection": CONFIG["SQLCL_CONNECTION_NAME"], "sql_summary": "attempted write to mark job reviewed"},
     {"rows": 0},
     "DENIED", "PRIVILEGE_SCOPE", "Read-only role blocked a write operation. This is expected in validation mode."),
    (7, "TENANT_A", "thread-antigravity-mcp-001", "oracle_memory/retrieve",
     {"query": "MCP saved connection setup", "top_k": 3},
     {"rows": 3, "quality": "usable"},
     "SUCCESS", None, None),
    (2, "TENANT_B", "thread-antigravity-mcp-002", "oracle_memory/retrieve",
     {"query": "onboarding validation checklist for MCP connections", "top_k": 3},
     {"rows": 1, "quality": "weak"},
     "WARNING", "RETRIEVAL_QUALITY", "Only one tenant-scoped memory chunk matched the query."),
]

try:
    cursor.executemany(
        """INSERT INTO antigravity_conversational_memory
            (tenant_id, thread_id, role, content, metadata_json, event_seq, event_time)
        VALUES (:1, :2, :3, :4, :5, :6, TO_TIMESTAMP(:7, 'YYYY-MM-DD HH24:MI:SS'))""",
        [(tenant, thread, role, content, json.dumps(metadata), event_seq, event_timestamp(event_seq))
         for event_seq, tenant, thread, role, content, metadata in conversation_rows],
    )
    cursor.executemany(
        """INSERT INTO antigravity_tool_logs
            (tenant_id, thread_id, tool_name, tool_input, tool_output, status, error_class, error_message, event_seq, event_time)
        VALUES (:1, :2, :3, :4, :5, :6, :7, :8, :9, TO_TIMESTAMP(:10, 'YYYY-MM-DD HH24:MI:SS'))""",
        [(tenant, thread, tool, json.dumps(tool_input), json.dumps(tool_output), status, error_class, error_message, event_seq, event_timestamp(event_seq))
         for event_seq, tenant, thread, tool, tool_input, tool_output, status, error_class, error_message in tool_log_rows],
    )
    connection.commit()
except Exception as exc:
    connection.rollback()
    raise RuntimeError(f"Step 6 insert failed and was rolled back: {exc}") from exc

memory_load_summary = pd.DataFrame([
    {"memory_stream": "conversational_memory", "rows_loaded": len(conversation_rows), "purpose": "Antigravity/user turns and grounded responses"},
    {"memory_stream": "operational_tool_logs", "rows_loaded": len(tool_log_rows), "purpose": "MCP tool call audit trail"},
])
display_df(memory_load_summary)
# Out:
#            memory_stream  rows_loaded  \
# 0  conversational_memory            4
# 1  operational_tool_logs            5
#
#                                          purpose
# 0  Antigravity/user turns and grounded responses
# 1                      MCP tool call audit trail

# %% [markdown]
# ## Step 10 - Query Operational Memory
#
# These queries are where the workflow becomes auditable. Instead of asking "why did the assistant answer that way?", we can inspect the execution trail:
#
# - which MCP tools ran,
# - which tenant/thread they belonged to,
# - which operations failed,
# - and whether failures were expected privilege boundaries or real runtime issues.

# %%
tool_status = run_sql("""
SELECT
    tenant_id,
    tool_name,
    status,
    COUNT(*) AS calls
FROM antigravity_tool_logs
GROUP BY tenant_id, tool_name, status
ORDER BY tenant_id, tool_name, status
""")

status_order = {"SUCCESS": 1, "WARNING": 2, "DENIED": 3, "ERROR": 4}
tool_status["status_rank"] = tool_status["status"].map(status_order).fillna(99)
tool_status = tool_status.sort_values(["tenant_id", "status_rank", "tool_name"]).drop(columns=["status_rank"])
tool_status["control_status"] = tool_status["status"].map({
    "SUCCESS": "OK",
    "DENIED": "CONTROLLED",
    "WARNING": "REVIEW",
    "ERROR": "ACTION_NEEDED",
}).fillna("REVIEW")

print("MCP operational call matrix:")
display_df(tool_status)
# Out:
# MCP operational call matrix:
#   tenant_id               tool_name   status  calls control_status
# 0  TENANT_A        list-connections  SUCCESS      1             OK
# 1  TENANT_A  oracle_memory/retrieve  SUCCESS      1             OK
# 3  TENANT_A                 run-sql  SUCCESS      1             OK
# 2  TENANT_A                 run-sql   DENIED      1     CONTROLLED
# 4  TENANT_B  oracle_memory/retrieve  WARNING      1         REVIEW

# %%
thread_timeline = run_sql("""
SELECT
    'CONVERSATION' AS event_kind,
    tenant_id,
    thread_id,
    role AS actor,
    DBMS_LOB.SUBSTR(content, 220, 1) AS summary,
    event_seq,
    event_time
FROM antigravity_conversational_memory
WHERE thread_id = :thread_id
UNION ALL
SELECT
    'MCP_TOOL' AS event_kind,
    tenant_id,
    thread_id,
    tool_name AS actor,
    status || CASE WHEN error_class IS NOT NULL THEN ' / ' || error_class ELSE '' END AS summary,
    event_seq,
    event_time
FROM antigravity_tool_logs
WHERE thread_id = :thread_id
ORDER BY event_seq, event_kind
""", {"thread_id": "thread-antigravity-mcp-001"})

thread_timeline = thread_timeline.rename(columns={"event_seq": "step"})
thread_timeline["event_time"] = pd.to_datetime(thread_timeline["event_time"]).dt.strftime("%H:%M:%S")

print("Single-thread Antigravity MCP execution timeline:")
display_df(thread_timeline)
# Out:
# Single-thread Antigravity MCP execution timeline:
#      event_kind tenant_id                   thread_id             actor  \
# 0  CONVERSATION  TENANT_A  thread-antigravity-mcp-001              user
# 1  CONVERSATION  TENANT_A  thread-antigravity-mcp-001         assistant
# 2      MCP_TOOL  TENANT_A  thread-antigravity-mcp-001  list-connections
# 3      MCP_TOOL  TENANT_A  thread-antigravity-mcp-001           run-sql
# 4      MCP_TOOL  TENANT_A  thread-antigravity-mcp-001           run-sql
# 5  CONVERSATION  TENANT_A  thread-antigravity-mcp-001         assistant
#
#                                              summary  step event_time
# 0  Can you inspect failed jobs from the Oracle su...     1   09:00:10
# 1  I will use SQLcl MCP tools to list connections...     2   09:00:20
# 2                                            SUCCESS     3   09:00:30
# 3                                            SUCCESS     4   09:00:40
# ...

# %%
audit_view = run_sql("""
SELECT
    tenant_id,
    thread_id,
    tool_name,
    status,
    error_class,
    error_message,
    created_at
FROM antigravity_tool_logs
WHERE status <> 'SUCCESS'
ORDER BY created_at DESC
""")

if not audit_view.empty:
    audit_view["control_status"] = audit_view["error_class"].map({
        "PRIVILEGE_SCOPE": "CONTROLLED",
        "RETRIEVAL_QUALITY": "REVIEW",
    }).fillna("ACTION_NEEDED")
    audit_view["control_interpretation"] = audit_view["error_class"].map({
        "PRIVILEGE_SCOPE": "Expected boundary: read-only mode blocked a write attempt.",
        "RETRIEVAL_QUALITY": "Retrieval quality signal captured for review.",
    }).fillna("Review required.")
    audit_view["created_at"] = pd.to_datetime(audit_view["created_at"]).dt.strftime("%H:%M:%S")

print("Controlled review signals:")
display_df(audit_view, "No non-success tool calls found.")
# Out:
# Controlled review signals:
#   tenant_id                   thread_id               tool_name   status  \
# 0  TENANT_B  thread-antigravity-mcp-002  oracle_memory/retrieve  WARNING
# 1  TENANT_A  thread-antigravity-mcp-001                 run-sql   DENIED
#
#          error_class                                      error_message  \
# 0  RETRIEVAL_QUALITY  Only one tenant-scoped memory chunk matched th...
# 1    PRIVILEGE_SCOPE  Read-only role blocked a write operation. This...
#
#   created_at control_status                             control_interpretation
# 0   11:30:33         REVIEW      Retrieval quality signal captured for review.
# 1   11:30:33     CONTROLLED  Expected boundary: read-only mode blocked a wr...

# %% [markdown]
# ## Step 11 - Insert Knowledge Memory
#
# These chunks represent the durable memory that should outlive a single Antigravity CLI session. They are written as tenant-scoped chunks so retrieval can enforce boundaries. In a production workflow, this is the layer Oracle AI Agent Memory manages through its package API. You are building it manually here so the structure is fully visible.
#
# The notebook uses deterministic demo embeddings later, so no external embedding service or API key is required.

# %%
knowledge_rows = [
    ("mcp_setup", "SQLcl MCP execution boundary",
     "Antigravity CLI should connect to Oracle AI Database through SQLcl MCP using sql -mcp. The assistant calls explicit tools instead of receiving unrestricted database access.",
     "Setup Guide", "high"),
    ("mcp_setup", "Saved SQLcl connections for MCP",
     "SQLcl MCP relies on saved SQLcl connection profiles stored under the user connection store. MCP-compatible connections should persist the password with savepwd so Antigravity CLI can launch the server reproducibly.",
     "Setup Guide", "high"),
    ("security", "Least privilege first",
     "Operational rollout should start with read-only database roles, schema allowlists, and explicit confirmation workflows for high-impact write operations.",
     "Engineering guidance", "high"),
    ("observability", "Tool logging baseline",
     "Log the tool name, thread ID, tenant ID, timestamp, status, and sanitized input and output summaries for every MCP tool call.",
     "Engineering guidance", "high"),
    ("langchain", "LangChain as orchestration glue",
     "LangChain is useful for declaring retrievers and composing retrieval-first pipelines, but security enforcement should stay in database privileges and runtime boundaries.",
     "Where LangChain adds value", "medium"),
    ("retrieval", "Retrieval quality failure mode",
     "Fluent but weakly grounded answers usually point to poor chunking, sparse metadata, weak retrieval settings, or a corpus that no longer matches real query patterns.",
     "Failure modes", "medium"),
    ("memory_model", "Antigravity memory versus Oracle memory",
     "Antigravity memory improves assistant continuity, while Oracle memory provides durable, queryable, governed system memory across users, sessions, and tools.",
     "Antigravity memory vs Oracle memory", "high"),
]

tenant_b_row = (
    "TENANT_B", "tenant_b_validation", "mcp_setup", "Tenant B onboarding note",
    "Tenant B allows read-only SQLcl MCP onboarding only after the connection alias is reviewed by the platform team.",
    {"article_section": "Tenant validation", "priority": "medium"},
)

insert_rows = [
    ("TENANT_A", "antigravity_mcp_oracle_ai_database_article", category, title, text,
     {"article_section": section, "priority": priority})
    for category, title, text, section, priority in knowledge_rows
] + [tenant_b_row]

try:
    cursor.executemany(
        """
        INSERT INTO antigravity_kb_chunks
            (tenant_id, source_name, category, title, chunk_text, metadata_json)
        VALUES (:1, :2, :3, :4, :5, :6)
        """,
        [(tenant, source, category, title, text, json.dumps(metadata))
        for tenant, source, category, title, text, metadata in insert_rows],
    )

    connection.commit()
except Exception as exc:
    connection.rollback()
    raise RuntimeError(f"Step 7 insert failed and was rolled back: {exc}") from exc

print(f"Inserted {len(insert_rows)} knowledge chunks.")
# Out:
# Inserted 8 knowledge chunks.

# %% [markdown]
# ### Where We Are
#
# The operational and audit layer is now in place:
#
# - SQLcl MCP boundary has been validated (or flagged for local setup).
# - Oracle AI Database memory tables exist and are populated with simulated Antigravity/MCP traces.
# - Tool call outcomes, including controlled failures, are stored and queryable.
#
# The notebook now shifts to the retrieval and grounding layer: lexical search, vector search, hybrid retrieval, and assembling evidence packages for the assistant.

# %% [markdown]
# ## Step 12 - When Should You Use Lexical Search?
#
# Lexical retrieval is important for exact phrases like `sql -mcp`, `savepwd`, connection aliases, error codes, and policy terms.
#
# This section tries Oracle Text first. If Oracle Text privileges are not available in your local database, the notebook falls back to a simple tenant-scoped `LIKE` search so the rest of the workflow remains runnable.

# %%
ORACLE_TEXT_READY = False
oracle_text_error = None

try:
    safe_drop_index("ANTIGRAVITY_KB_TEXT_IDX")
    execute_ddl("""
    CREATE INDEX antigravity_kb_text_idx
    ON antigravity_kb_chunks(chunk_text)
    INDEXTYPE IS CTXSYS.CONTEXT
    """)
    cursor.execute("BEGIN CTX_DDL.SYNC_INDEX('ANTIGRAVITY_KB_TEXT_IDX'); END;")
    connection.commit()
    ORACLE_TEXT_READY = True
    print("Oracle Text index is ready.")
except Exception as exc:
    connection.rollback()
    oracle_text_error = str(exc)
    print("Oracle Text is not available in this environment. Falling back to LIKE search.")


def text_query_terms(query: str) -> list[str]:
    stopwords = {"and", "or", "the", "with", "what", "when", "where", "should", "does", "from", "this", "that"}
    terms = []
    for term in re.findall(r"[A-Za-z0-9_\-]+", query.lower()):
        if len(term) > 2 and term not in stopwords:
            terms.append(term)
    return terms[:8]


def like_search(query: str, tenant_id: str = "TENANT_A", top_k: int = 5) -> pd.DataFrame:
    terms = text_query_terms(query)
    if not terms:
        return pd.DataFrame(columns=["chunk_id", "tenant_id", "category", "title", "chunk_text", "lexical_score"])

    params = {"tenant_id": tenant_id}
    predicates = []
    score_parts = []
    for idx, term in enumerate(terms):
        pred_key = f"pred_term_{idx}"
        score_key = f"score_term_{idx}"
        params[pred_key] = f"%{term}%"
        params[score_key] = f"%{term}%"
        predicates.append(f"LOWER(chunk_text) LIKE :{pred_key}")
        score_parts.append(f"CASE WHEN LOWER(chunk_text) LIKE :{score_key} THEN 1 ELSE 0 END")

    sql = f"""
    SELECT
        chunk_id,
        tenant_id,
        category,
        title,
        DBMS_LOB.SUBSTR(chunk_text, 500, 1) AS chunk_text,
        ({' + '.join(score_parts)}) AS lexical_score
    FROM antigravity_kb_chunks
    WHERE tenant_id = :tenant_id
      AND ({' OR '.join(predicates)})
    ORDER BY lexical_score DESC, chunk_id
    FETCH FIRST {int(top_k)} ROWS ONLY
    """
    return run_sql(sql, params)


def oracle_text_query(query: str) -> str:
    terms = text_query_terms(query)
    return " OR ".join(terms) if terms else query


def lexical_search(query: str, tenant_id: str = "TENANT_A", top_k: int = 5) -> pd.DataFrame:
    top_k = int(top_k)
    if ORACLE_TEXT_READY:
        try:
            return run_sql(f"""
            SELECT
                chunk_id,
                tenant_id,
                category,
                title,
                DBMS_LOB.SUBSTR(chunk_text, 500, 1) AS chunk_text,
                SCORE(1) AS lexical_score
            FROM antigravity_kb_chunks
            WHERE tenant_id = :tenant_id
              AND CONTAINS(chunk_text, :query, 1) > 0
            ORDER BY lexical_score DESC
            FETCH FIRST {top_k} ROWS ONLY
            """, {"tenant_id": tenant_id, "query": oracle_text_query(query)})
        except Exception as exc:
            print("Oracle Text query could not be parsed for this input. Falling back to LIKE search.")
            connection.rollback()
            return like_search(query, tenant_id=tenant_id, top_k=top_k)

    return like_search(query, tenant_id=tenant_id, top_k=top_k)


lexical_results = lexical_search("Antigravity MCP saved connection savepwd", tenant_id="TENANT_A", top_k=3)
display_df(lexical_results)
# Out:
# Oracle Text is not available in this environment. Falling back to LIKE search.
#    chunk_id tenant_id       category                            title  \
# 0         2  TENANT_A      mcp_setup  Saved SQLcl connections for MCP
# 1         1  TENANT_A      mcp_setup     SQLcl MCP execution boundary
# 2         4  TENANT_A  observability            Tool logging baseline
#
#                                           chunk_text  lexical_score
# 0  SQLcl MCP relies on saved SQLcl connection pro...              5
# 1  Antigravity CLI should connect to Oracle AI Da...              2
# 2  Log the tool name, thread ID, tenant ID, times...              1

# %% [markdown]
# **What this fallback means:**
#
# Oracle Text requires CTXSYS privileges which may not be available in all local environments. The LIKE fallback keeps the notebook runnable and produces correct results for small corpora, but loses relevance ranking for larger datasets.
#
# For this notebook, `FALLBACK` is an acceptable portable demo path. Enable Oracle Text only when you want production lexical ranking.
#
# **How to enable the production path:**
#
# Grant `CTXSYS.CONTEXT` indextype privileges to your Oracle user and rerun this cell. No other code changes are needed.

# %% [markdown]
# **DEVELOPER PATTERN: Lexical retrieval**
#
# Use this when: Queries contain exact setup terms like `sql -mcp`, `savepwd`, error codes, object names.
#
# Minimal call: `lexical_search("savepwd connection alias", tenant_id="TENANT_A", top_k=3)`
#
# Expected output: DataFrame with `lexical_score` ranked by term match count.
#
# Adapt for your app: Replace LIKE fallback with Oracle Text once CTXSYS privileges are available.
#
# Production note: Schedule `CTX_DDL.SYNC_INDEX` to keep the text index fresh after bulk inserts.

# %% [markdown]
# ## Step 13 - How Does Vector Search Work in the Portable Demo?
#
# Vector search is part of the companion article's Oracle AI Database memory story. In a real application, embeddings would usually come from a model and be indexed with Oracle AI Database vector capabilities.
#
# For a portable notebook, this section uses deterministic domain embeddings. The dimensions are intentionally meaningful: MCP boundary, SQLcl runtime, Oracle AI Database, security, observability, memory, retrieval, and LangChain. That makes the output easier to inspect than a random vector demo.

# %%
import hashlib
import numpy as np

TERM_GROUPS = {
    "antigravity_interface": ["cursor", "cli", "assistant", "conversation", "interaction", "client"],
    "mcp_boundary": ["mcp", "tool", "tools", "contract", "boundary", "explicit", "server"],
    "sqlcl_runtime": ["sqlcl", "sql", "savepwd", "connection", "connections", "alias", "profile"],
    "oracle_ai_database": ["oracle", "database", "ai", "table", "tables", "json", "vector", "text"],
    "security": ["privilege", "privileges", "role", "roles", "allowlist", "confirmation", "read-only", "readonly"],
    "observability": ["log", "logs", "logging", "audit", "timestamp", "status", "trace", "tool"],
    "memory": ["memory", "history", "durable", "system", "session", "tenant"],
    "retrieval": ["retrieval", "retrieve", "semantic", "lexical", "hybrid", "evidence", "grounded"],
    "langchain": ["langchain", "orchestration", "retriever", "pipeline", "runnable"],
    "reliability": ["failure", "fallback", "validation checklist", "diagnostic", "quality", "weak"],
}

EMBEDDING_DIM = len(TERM_GROUPS)
EMBEDDING_LABELS = list(TERM_GROUPS.keys())


def tokenize(text: str) -> list[str]:
    return [token.lower() for token in re.findall(r"[A-Za-z0-9_\-]+", text)]


def demo_embed(text: str, dim: int = EMBEDDING_DIM) -> np.ndarray:
    tokens = tokenize(text)
    vector = np.zeros(dim, dtype=float)
    for idx, label in enumerate(EMBEDDING_LABELS):
        terms = TERM_GROUPS[label]
        vector[idx] = sum(1.0 for token in tokens for term in terms if token == term or token.startswith(term))

    # Add a small deterministic signal so ties remain stable without hiding the semantic dimensions.
    for token in tokens:
        digest = hashlib.sha256(token.encode("utf-8")).hexdigest()
        vector[int(digest[:8], 16) % dim] += 0.05

    norm = np.linalg.norm(vector)
    if norm == 0:
        return vector
    return vector / norm


def vector_to_json(vector: np.ndarray) -> str:
    return json.dumps([round(float(value), 6) for value in vector.tolist()])


def parse_embedding(value) -> np.ndarray:
    value = lob_to_text(value)
    if isinstance(value, np.ndarray):
        return value.astype(float)
    if isinstance(value, list):
        return np.array(value, dtype=float)
    if isinstance(value, str):
        return np.array(json.loads(value), dtype=float)
    raise TypeError(f"Unsupported embedding value type: {type(value)!r}")


def cosine_similarity(a: np.ndarray, b: np.ndarray) -> float:
    denominator = np.linalg.norm(a) * np.linalg.norm(b)
    if denominator == 0:
        return 0.0
    return float(np.dot(a, b) / denominator)


chunk_rows = run_sql("SELECT chunk_id, chunk_text FROM antigravity_kb_chunks ORDER BY chunk_id")
for _, row in chunk_rows.iterrows():
    vector = demo_embed(row["chunk_text"])
    cursor.execute(
        "UPDATE antigravity_kb_chunks SET embedding_json = :embedding_json WHERE chunk_id = :chunk_id",
        {"embedding_json": vector_to_json(vector), "chunk_id": int(row["chunk_id"])},
    )
connection.commit()

embedding_profile = pd.DataFrame({
    "dimension": EMBEDDING_LABELS,
    "purpose": [
        "Antigravity CLI interface",
        "MCP tool boundary and explicit contracts",
        "SQLcl runtime, saved connections, savepwd",
        "Oracle AI Database multimodal storage",
        "Privileges, confirmation, read-only controls",
        "Tool logs, audit, traceability",
        "Durable system memory",
        "Lexical, semantic, and hybrid retrieval",
        "LangChain orchestration",
        "Validation checks, fallback, diagnostics",
    ],
})

print(f"Stored deterministic semantic demo embeddings for {len(chunk_rows)} chunks.")
display(embedding_profile)
# Out:
# Stored deterministic semantic demo embeddings for 8 chunks.
#                dimension                                       purpose
# 0  antigravity_interface                     Antigravity CLI interface
# 1           mcp_boundary      MCP tool boundary and explicit contracts
# 2          sqlcl_runtime     SQLcl runtime, saved connections, savepwd
# 3     oracle_ai_database         Oracle AI Database multimodal storage
# 4               security  Privileges, confirmation, read-only controls
# 5          observability                Tool logs, audit, traceability
# 6                 memory                         Durable system memory
# 7              retrieval       Lexical, semantic, and hybrid retrieval
# 8              langchain                       LangChain orchestration
# 9            reliability      Validation checks, fallback, diagnostics

# %%
NATIVE_VECTOR_READY = False
native_vector_error = None

try:
    execute_ddl(f"ALTER TABLE antigravity_kb_chunks ADD (embedding_vector VECTOR({EMBEDDING_DIM}, FLOAT32))")
    rows_for_vector = run_sql("SELECT chunk_id, embedding_json FROM antigravity_kb_chunks ORDER BY chunk_id")
    for _, row in rows_for_vector.iterrows():
        vector_json = vector_to_json(parse_embedding(row["embedding_json"])) if "parse_embedding" in globals() else json.dumps(row["embedding_json"])
        cursor.execute(
            "UPDATE antigravity_kb_chunks SET embedding_vector = TO_VECTOR(:embedding_json) WHERE chunk_id = :chunk_id",
            {"embedding_json": vector_json, "chunk_id": int(row["chunk_id"])},
        )
    connection.commit()
    NATIVE_VECTOR_READY = True
    print("Oracle AI Database native VECTOR path is ready.")
except Exception as exc:
    connection.rollback()
    native_vector_error = str(exc)
    print("Native VECTOR path is not available in this environment; using portable Python cosine fallback.")

vector_mode = pd.DataFrame([{
    "vector_path": "Oracle AI Database native VECTOR" if NATIVE_VECTOR_READY else "Portable cosine fallback",
    "embedding_dimensions": EMBEDDING_DIM,
    "stored_representation": "VECTOR column + JSON backup" if NATIVE_VECTOR_READY else "JSON embedding column",
    "purpose": "Rank memory chunks by semantic similarity",
}])
display_df(vector_mode)
# Out:
# Oracle AI Database native VECTOR path is ready.
#                         vector_path  embedding_dimensions  \
# 0  Oracle AI Database native VECTOR                    10
#
#          stored_representation                                    purpose
# 0  VECTOR column + JSON backup  Rank memory chunks by semantic similarity

# %% [markdown]
# **What this fallback means:**
#
# Native VECTOR requires Oracle AI Database with vector support enabled. The Python cosine fallback produces identical rankings for this demo corpus. For datasets over a few thousand chunks, native VECTOR indexes are significantly faster.
#
# **How to enable the production path:**
#
# Use Oracle AI Database 26ai and confirm VECTOR column support. The `embedding_vector` column and `TO_VECTOR()` calls in the code are already wired, only the environment needs to change.

# %%
def vector_search(query: str, tenant_id: str = "TENANT_A", top_k: int = 5) -> pd.DataFrame:
    top_k = int(top_k)
    query_vector = demo_embed(query)
    query_vector_json = vector_to_json(query_vector)

    if NATIVE_VECTOR_READY:
        try:
            return run_sql(f"""
            SELECT
                chunk_id,
                tenant_id,
                category,
                title,
                DBMS_LOB.SUBSTR(chunk_text, 500, 1) AS chunk_text,
                VECTOR_DISTANCE(embedding_vector, TO_VECTOR(:query_vector), COSINE) AS vector_distance,
                1 - VECTOR_DISTANCE(embedding_vector, TO_VECTOR(:query_vector), COSINE) AS vector_score
            FROM antigravity_kb_chunks
            WHERE tenant_id = :tenant_id
            ORDER BY vector_distance
            FETCH FIRST {top_k} ROWS ONLY
            """, {"tenant_id": tenant_id, "query_vector": query_vector_json})
        except Exception as exc:
            print("Native vector search failed. Falling back to Python cosine search.")
            connection.rollback()

    rows = run_sql("""
    SELECT
        chunk_id,
        tenant_id,
        category,
        title,
        DBMS_LOB.SUBSTR(chunk_text, 500, 1) AS chunk_text,
        embedding_json
    FROM antigravity_kb_chunks
    WHERE tenant_id = :tenant_id
    """, {"tenant_id": tenant_id})

    scored = []
    for _, row in rows.iterrows():
        stored_vector = parse_embedding(row["embedding_json"])
        score = cosine_similarity(query_vector, stored_vector)
        scored.append({
            "chunk_id": row["chunk_id"],
            "tenant_id": row["tenant_id"],
            "category": row["category"],
            "title": row["title"],
            "chunk_text": row["chunk_text"],
            "vector_distance": 1 - score,
            "vector_score": score,
        })

    return pd.DataFrame(scored).sort_values("vector_score", ascending=False).head(top_k).reset_index(drop=True)


semantic_results = vector_search("How should Antigravity use SQLcl MCP safely with saved connections and least privilege?", tenant_id="TENANT_A", top_k=3)
print("Vector search candidates:")
display_df(semantic_results)
plot_vector_lollipop(semantic_results)
# Out:
# Vector search candidates:
#    chunk_id tenant_id   category                            title  \
# 0         2  TENANT_A  mcp_setup  Saved SQLcl connections for MCP
# 1         1  TENANT_A  mcp_setup     SQLcl MCP execution boundary
# 2         3  TENANT_A   security            Least privilege first
#
#                                           chunk_text  vector_distance  \
# 0  SQLcl MCP relies on saved SQLcl connection pro...         0.030019
# 1  Antigravity CLI should connect to Oracle AI Da...         0.419404
# 2  Operational rollout should start with read-onl...         0.712529
#
#    vector_score
# 0      0.969981
# 1      0.580596
# 2      0.287471

# %% [markdown]
# **DEVELOPER PATTERN: Vector search**
#
# Use this when: Users paraphrase intent or ask conceptual questions without using exact setup terms.
#
# Minimal call: `vector_search("how should Antigravity connect safely", tenant_id="TENANT_A", top_k=3)`
#
# Expected output: DataFrame with `vector_score` 0.0–1.0, ranked by cosine similarity.
#
# Adapt for your app: Replace `demo_embed()` with your embedding model; keep the same function signature.
#
# Production note: Native VECTOR indexes outperform Python cosine at scale. The fallback is for portability only.

# %% [markdown]
# ## Step 14 - Hybrid Retrieval
#
# Hybrid retrieval combines:
#
# - lexical precision for exact setup terms,
# - semantic similarity for paraphrases,
# - tenant filtering for governance.
#
# This is the pattern the article is advocating: MCP controls execution, while Oracle memory provides durable and governed retrieval.

# %%
def normalize_series(values: pd.Series) -> pd.Series:
    if values.empty:
        return values
    max_value = values.max()
    min_value = values.min()
    if max_value == min_value:
        return pd.Series([1.0] * len(values), index=values.index)
    return (values - min_value) / (max_value - min_value)


def hybrid_search(query: str, tenant_id: str = "TENANT_A", top_k: int = 5) -> pd.DataFrame:
    lexical = lexical_search(query, tenant_id=tenant_id, top_k=10)
    semantic = vector_search(query, tenant_id=tenant_id, top_k=10)

    combined: dict[int, dict] = {}

    if lexical is not None and not lexical.empty:
        lexical = lexical.copy()
        lexical["lexical_score_norm"] = normalize_series(lexical["lexical_score"].astype(float))
        for _, row in lexical.iterrows():
            chunk_id = int(row["chunk_id"])
            combined.setdefault(chunk_id, row.to_dict())
            combined[chunk_id]["lexical_score_norm"] = float(row["lexical_score_norm"])

    if semantic is not None and not semantic.empty:
        semantic = semantic.copy()
        semantic["vector_score_norm"] = normalize_series(semantic["vector_score"].astype(float))
        for _, row in semantic.iterrows():
            chunk_id = int(row["chunk_id"])
            combined.setdefault(chunk_id, row.to_dict())
            combined[chunk_id]["vector_score_norm"] = float(row["vector_score_norm"])
            combined[chunk_id]["vector_score"] = float(row["vector_score"])

    records = []
    for record in combined.values():
        lexical_part = float(record.get("lexical_score_norm", 0.0) or 0.0)
        vector_part = float(record.get("vector_score_norm", 0.0) or 0.0)
        operational_boost = 0.10 if record.get("category") in ["mcp_setup", "security", "observability"] else 0.0
        record["hybrid_score"] = round((0.45 * lexical_part) + (0.45 * vector_part) + operational_boost, 4)
        records.append(record)

    if not records:
        return pd.DataFrame(columns=["chunk_id", "tenant_id", "category", "title", "chunk_text", "hybrid_score"])

    columns = ["chunk_id", "tenant_id", "category", "title", "chunk_text", "hybrid_score"]
    return pd.DataFrame(records).sort_values("hybrid_score", ascending=False)[columns].head(top_k).reset_index(drop=True)


hybrid_results = hybrid_search("Antigravity MCP should use saved SQLcl connections, tool boundaries, logging, and least privilege", top_k=3)
print("Hybrid retrieval ranking:")
display_df(hybrid_results)
plot_hybrid_signal_mix("Antigravity MCP should use saved SQLcl connections, tool boundaries, logging, and least privilege", top_k=3)
# Out:
# Hybrid retrieval ranking:
#    chunk_id tenant_id       category                            title  \
# 0         2  TENANT_A      mcp_setup  Saved SQLcl connections for MCP
# 1         1  TENANT_A      mcp_setup     SQLcl MCP execution boundary
# 2         4  TENANT_A  observability            Tool logging baseline
#
#                                           chunk_text  hybrid_score
# 0  SQLcl MCP relies on saved SQLcl connection pro...        1.0000
# 1  Antigravity CLI should connect to Oracle AI Da...        0.6703
# 2  Log the tool name, thread ID, tenant ID, times...        0.4633

# %% [markdown]
# **DEVELOPER PATTERN: Hybrid retrieval**
#
# Use this when: Production queries mix exact terms and paraphrased intent.
#
# Minimal call: `hybrid_search("MCP saved connections least privilege", tenant_id="TENANT_A", top_k=3)`
#
# Expected output: DataFrame with `hybrid_score` combining lexical + vector + operational boost.
#
# Adapt for your app: Tune the 0.45/0.45/0.10 weights to match your corpus and query patterns.
#
# Production note: The operational boost rewards mcp_setup, security, and observability categories. Adjust categories to match your domain.

# %% [markdown]
# ## Step 15 - Retrieval-First Grounding Policy
#
# This notebook does not call an LLM. Instead, it builds the context package that an operational assistant should use before generating a final answer.
#
# Policy:
#
# 1. Retrieve tenant-scoped memory first.
# 2. If evidence is weak or missing, say context is insufficient.
# 3. Keep the response grounded in retrieved memory and tool outcomes.
# 4. Log tool calls and retrieval attempts.

# %%
def build_grounding_package(question: str, tenant_id: str = "TENANT_A", min_score: float = 0.20) -> dict:
    evidence = hybrid_search(question, tenant_id=tenant_id, top_k=4)
    if evidence.empty or float(evidence.iloc[0]["hybrid_score"]) < min_score:
        return {
            "status": "INSUFFICIENT_CONTEXT",
            "question": question,
            "tenant_id": tenant_id,
            "evidence": [],
            "instruction": "Ask a clarifying question or run a safer retrieval path before answering.",
        }

    evidence_items = evidence.to_dict(orient="records")
    for item in evidence_items:
        if isinstance(item.get("chunk_text"), str) and len(item["chunk_text"]) > 800:
            item["chunk_text"] = item["chunk_text"][:800] + "... [truncated]"
    return {
        "status": "READY",
        "question": question,
        "tenant_id": tenant_id,
        "evidence": evidence_items,
        "instruction": "Answer using only the retrieved evidence and relevant tool outcomes.",
    }


grounding_package = build_grounding_package(
    "What should we log first when Antigravity uses SQLcl MCP?",
    tenant_id="TENANT_A",
)

evidence_table = pd.DataFrame(grounding_package["evidence"])
print("Retrieval-first grounding package:")
print(f"Status: {grounding_package['status']}")
print(f"Instruction: {grounding_package['instruction']}")

evidence_columns = ["title", "category", "hybrid_score", "chunk_text"]
if evidence_table.empty:
    display_df(evidence_table, empty_message="No evidence returned for this grounding package.")
else:
    display_df(evidence_table.reindex(columns=evidence_columns))
# Out:
# Retrieval-first grounding package:
# Status: READY
# Instruction: Answer using only the retrieved evidence and relevant tool outcomes.
#                              title       category  hybrid_score  \
# 0  Saved SQLcl connections for MCP      mcp_setup        1.0000
# 1     SQLcl MCP execution boundary      mcp_setup        0.8850
# 2            Tool logging baseline  observability        0.6024
# 3            Least privilege first       security        0.1442
#
#                                           chunk_text
# 0  SQLcl MCP relies on saved SQLcl connection pro...
# 1  Antigravity CLI should connect to Oracle AI Da...
# 2  Log the tool name, thread ID, tenant ID, times...
# 3  Operational rollout should start with read-onl...

# %% [markdown]
# ## Step 16 - Interactive Retrieval Playground
#
# Use this section to test different Antigravity-style questions against the Oracle AI Database memory layer. It helps show how the same memory substrate supports MCP setup, security boundaries, logging, and LangChain orchestration.
#
# Change `selected_question` to one of the examples or write your own.

# %%
question_bank = {
    "mcp_setup": "How should Antigravity CLI connect to Oracle AI Database through SQLcl MCP?",
    "tool_boundary": "Why is MCP safer than giving the assistant implicit database access?",
    "memory_split": "What should stay in Antigravity memory and what should stay in Oracle memory?",
    "logging": "What should be logged when Antigravity uses SQLcl MCP tools?",
    "langchain": "Where does LangChain fit without becoming the enforcement layer?",
}


def retrieval_playground(selected_question: str = "tool_boundary", tenant_id: str = "TENANT_A", top_k: int = 4):
    question = question_bank.get(selected_question, selected_question)
    results = hybrid_search(question, tenant_id=tenant_id, top_k=top_k)
    print(f"Selected question: {selected_question}")
    print(question)
    display_df(results[["title", "category", "hybrid_score", "chunk_text"]])
    plot_evidence_radar(results, "Playground evidence profile")
    return results


playground_results = retrieval_playground("tool_boundary")
# Out:
# Selected question: tool_boundary
# Why is MCP safer than giving the assistant implicit database access?
#                              title       category  hybrid_score  \
# 0     SQLcl MCP execution boundary      mcp_setup        1.0000
# 1  Saved SQLcl connections for MCP      mcp_setup        0.2149
# 2            Tool logging baseline  observability        0.2046
# 3            Least privilege first       security        0.1833
#
#                                           chunk_text
# 0  Antigravity CLI should connect to Oracle AI Da...
# 1  SQLcl MCP relies on saved SQLcl connection pro...
# 2  Log the tool name, thread ID, tenant ID, times...
# 3  Operational rollout should start with read-onl...

# %% [markdown]
# ## Step 17 - Generate Antigravity Prompt Pack
#
# This cell generates prompts you can paste into Antigravity after SQLcl MCP is configured. The prompts are intentionally constrained: they ask Antigravity to use MCP tools safely and avoid writes unless explicitly approved.

# %%
antigravity_prompt_pack = [
    {
        "scenario": "MCP discovery",
        "safe_prompt": "Use SQLcl MCP to list available saved connections. Do not run DML or DDL.",
    },
    {
        "scenario": "Read-only inspection",
        "safe_prompt": "Use the read-only SQLcl MCP connection to inspect accessible schemas and return a short summary.",
    },
    {
        "scenario": "Grounded answer",
        "safe_prompt": "Retrieve Oracle AI Database memory about SQLcl MCP setup and answer only from retrieved evidence.",
    },
    {
        "scenario": "Boundary explanation",
        "safe_prompt": "Explain the roles of Antigravity CLI, SQLcl MCP, Oracle AI Database memory, and LangChain.",
    },
]

prompt_pack_df = pd.DataFrame(antigravity_prompt_pack)
print("Antigravity prompt pack:")
display_df(prompt_pack_df)
# Out:
# Antigravity prompt pack:
#                scenario                                        safe_prompt
# 0         MCP discovery  Use SQLcl MCP to list available saved connecti...
# 1  Read-only inspection  Use the read-only SQLcl MCP connection to insp...
# 2       Grounded answer  Retrieve Oracle AI Database memory about SQLcl...
# 3  Boundary explanation  Explain the roles of Antigravity CLI, SQLcl MC...

# %% [markdown]
# ## Optional Step 18 - Oracle AI Agent Memory Package
#
# This section is optional. The core Oracle AI Database memory workflow is already complete after Steps 4 through 14.
#
# Oracle AI Agent Memory is the application-facing Python package that sits on top of Oracle AI Database. It manages threads, durable memories, scoped retrieval, and prompt-ready memory retrieval.
#
# This section follows the Oracle Agent Memory documentation flow:
#
# 1. initialize `OracleAgentMemory`,
# 2. create a thread,
# 3. add messages,
# 4. add durable memory,
# 5. retrieve memory with `SearchScope`.
#
# The Oracle documentation initializes Agent Memory with `oracledb.SessionPool`, `Embedder`, and `Llm`. This notebook uses the same database-pool pattern, but keeps the model layer local by default:
#
# - `oracledb.SessionPool` uses the existing `.env` Oracle settings.
# - `LocalAntigravityEmbedder` is a deterministic local embedder for a no-billing notebook demo.
# - `llm=None` and `MemoryExtractionConfig(extract_memories=False)` avoid external LLM calls.
#
# Jupyter may show a warning when the package's synchronous methods are called from the notebook's async kernel context. The warning is noisy but harmless for this local demo; application code can use the package's async methods directly.
#
# For production, replace `LocalAntigravityEmbedder` with a supported embedding model and optionally configure an LLM. For local Podman runs, use a dedicated application user/tablespace for Agent Memory. Creating Agent Memory JSON objects as `SYSTEM` can fail because the `SYSTEM` tablespace is not suitable for those objects.
#
# If you use the package-managed schema in production, run schema setup with a user that has `CREATE JOB` or an equivalent scheduler-job privilege, or use a managed schema setup flow. Without that privilege, the expired-record purge job cannot be created and expired messages or memories will not be purged automatically.

# %%
from importlib import metadata, util

import contextlib
import hashlib
import io
import re
import uuid
import warnings
import numpy as np
import oracledb
import pandas as pd

warnings.filterwarnings(
    "ignore",
    message=r"You are calling an asynchronous method.*",
    category=UserWarning,
    module=r"oracleagentmemory.*",
)
warnings.filterwarnings(
    "ignore",
    message=r"The managed expired-record purge job does not exist.*",
    category=UserWarning,
    module=r"oracleagentmemory.*",
)

ORACLE_AGENT_MEMORY_READY = util.find_spec("oracleagentmemory") is not None
oracle_agent_memory_version = None
oracle_agent_memory_error = None
IEmbedder = object
SearchScope = None
OracleAgentMemory = None

if ORACLE_AGENT_MEMORY_READY:
    try:
        from oracleagentmemory.apis.embedders.embedder import IEmbedder
        from oracleagentmemory.apis.searchscope import SearchScope
        from oracleagentmemory.core import MemoryExtractionConfig
        from oracleagentmemory.core.oracleagentmemory import OracleAgentMemory
        try:
            oracle_agent_memory_version = metadata.version("oracleagentmemory")
        except metadata.PackageNotFoundError:
            oracle_agent_memory_version = "installed"
    except Exception as exc:
        ORACLE_AGENT_MEMORY_READY = False
        oracle_agent_memory_error = str(exc)

AGENT_MEMORY_RUN_ID = uuid.uuid4().hex[:8]
AGENT_MEMORY_USER_ID = f"notebook_user_{AGENT_MEMORY_RUN_ID}"
AGENT_MEMORY_AGENT_ID = "antigravity_cli"

print(
    "Oracle AI Agent Memory package:",
    "PASS" if ORACLE_AGENT_MEMORY_READY else "OPTIONAL - install oracleagentmemory to use the package API",
)
if oracle_agent_memory_version:
    print(f"Package version: {oracle_agent_memory_version}")
if oracle_agent_memory_error:
    print("Import detail:", oracle_agent_memory_error)
print("Agent Memory demo scope:", AGENT_MEMORY_USER_ID)
# Out:
# Oracle AI Agent Memory package: PASS
# Package version: 26.6.0
# Agent Memory demo scope: notebook_user_e93b0211

# %%
class LocalAntigravityEmbedder(IEmbedder):
    """Deterministic local embedder for portable, no-billing demos.

    Oracle Agent Memory expects a 2D matrix-like return value from embed().
    This class returns numpy arrays shaped as (rows, dimensions).
    """

    def __init__(self, dimensions: int = 32):
        self.model = "local-cursor-deterministic-embedder"
        self.dimensions = dimensions

    def _embed_one(self, text: str) -> np.ndarray:
        vector = np.zeros(self.dimensions, dtype=np.float32)
        tokens = re.findall(r"[A-Za-z0-9_\-]+", str(text).lower())

        for token in tokens:
            digest = hashlib.sha256(token.encode("utf-8")).digest()
            index = int.from_bytes(digest[:4], "big") % self.dimensions
            vector[index] += 1.0 + (len(token) % 5) / 10.0

        norm = np.linalg.norm(vector)
        if norm:
            vector = vector / norm

        return vector

    def embed(self, input, **kwargs):
        if isinstance(input, str):
            return np.asarray([self._embed_one(input)], dtype=np.float32)

        return np.asarray([self._embed_one(item) for item in input], dtype=np.float32)

    async def embed_async(self, input, **kwargs):
        return self.embed(input, **kwargs)


test_embedding = LocalAntigravityEmbedder(dimensions=32).embed("test")
print("LocalAntigravityEmbedder is ready.")
print("Embedding shape:", test_embedding.shape)
# Out:
# LocalAntigravityEmbedder is ready.
# Embedding shape: (1, 32)

# %%
required = ["ORACLE_USER", "ORACLE_PASSWORD", "ORACLE_DSN"]
missing = [key for key in required if not CONFIG[key]]
if missing:
    raise RuntimeError(f"Missing required Oracle settings in .env: {missing}")

print("CONFIG ORACLE_USER: <configured .env user>")
print("CONFIG SQLCL_CONNECTION_NAME:", CONFIG["SQLCL_CONNECTION_NAME"])

db_pool = oracledb.SessionPool(
    user=CONFIG["ORACLE_USER"],
    password=CONFIG["ORACLE_PASSWORD"],
    dsn=CONFIG["ORACLE_DSN"],
    min=1,
    max=4,
    increment=1,
)

with db_pool.acquire() as agent_memory_check_connection:
    agent_memory_check_cursor = agent_memory_check_connection.cursor()
    current_user = agent_memory_check_cursor.execute("SELECT USER FROM dual").fetchone()[0]
    current_container = agent_memory_check_cursor.execute(
        "SELECT SYS_CONTEXT('USERENV', 'CON_NAME') FROM dual"
    ).fetchone()[0]
    default_tablespace = agent_memory_check_cursor.execute(
        "SELECT default_tablespace FROM user_users"
    ).fetchone()[0]

AGENT_MEMORY_SCHEMA_READY = (
    current_user.upper() != "SYSTEM"
    and default_tablespace.upper() != "SYSTEM"
)

agent_memory_readiness = pd.DataFrame(
    [
        {
            "check": "Oracle user",
            "value": "<configured .env user>",
            "status": "READY" if current_user.upper() != "SYSTEM" else "ACTION_NEEDED",
            "detail": "Use a dedicated Antigravity memory schema for Agent Memory objects.",
        },
        {
            "check": "Container",
            "value": current_container,
            "status": "READY",
            "detail": "Local Podman database should normally use FREEPDB1.",
        },
        {
            "check": "Default tablespace",
            "value": "<configured default tablespace>",
            "status": "READY" if default_tablespace.upper() != "SYSTEM" else "ACTION_NEEDED",
            "detail": "Agent Memory JSON objects need an application tablespace with automatic segment space management.",
        },
        {
            "check": "Embedder",
            "value": "LocalAntigravityEmbedder",
            "status": "READY",
            "detail": "No external model billing is required for this notebook demo.",
        },
    ]
)

display_df(agent_memory_readiness)

if not AGENT_MEMORY_SCHEMA_READY:
    print("Agent Memory package demo will be skipped for this schema.")
    print("Create or use a dedicated Antigravity memory user before running the package-backed demo:")
    print("""
-- Run as SYSTEM in FREEPDB1, for example through SQLcl or Podman sqlplus.
CREATE TABLESPACE antigravity_memory_ts
DATAFILE '/opt/oracle/oradata/FREE/FREEPDB1/antigravity_memory_ts01.dbf'
SIZE 200M
AUTOEXTEND ON NEXT 100M
SEGMENT SPACE MANAGEMENT AUTO;

CREATE USER antigravity_memory IDENTIFIED BY "CHOOSE_A_STRONG_PASSWORD";
GRANT CREATE SESSION, CREATE TABLE, CREATE SEQUENCE, CREATE VIEW, CREATE PROCEDURE TO antigravity_memory;
ALTER USER antigravity_memory DEFAULT TABLESPACE antigravity_memory_ts;
ALTER USER antigravity_memory QUOTA UNLIMITED ON antigravity_memory_ts;
""")
# Out:
# CONFIG ORACLE_USER: <configured .env user>
# CONFIG SQLCL_CONNECTION_NAME: antigravity_mcp
#                 check                            value status  \
# 0         Oracle user           <configured .env user>  READY
# 1           Container          FREESQLPRD_SCHEMA_PDB01  READY
# 2  Default tablespace  <configured default tablespace>  READY
# 3            Embedder         LocalAntigravityEmbedder  READY
#
#                                               detail
# 0  Use a dedicated Antigravity memory schema for ...
# 1  Local Podman database should normally use FREE...
# 2  Agent Memory JSON objects need an application ...
# 3  No external model billing is required for this...

# %%
agent_memory = None
agent_memory_thread = None
agent_memory_results = []
agent_memory_schema_notes = []
agent_memory_init_error = None

if ORACLE_AGENT_MEMORY_READY and AGENT_MEMORY_SCHEMA_READY:
    agent_memory_stderr = io.StringIO()
    try:
        with contextlib.redirect_stderr(agent_memory_stderr):
            agent_memory = OracleAgentMemory(
                connection=db_pool,
                embedder=LocalAntigravityEmbedder(dimensions=32),
                llm=None,
                memory_extraction_config=MemoryExtractionConfig(extract_memories=False),
                schema_policy="create_if_necessary",
                memory_store_id="ag_oam_local",
            )
    except Exception as exc:
        agent_memory = None
        agent_memory_init_error = str(exc).split("\n")[0]
        agent_memory_schema_notes.append(
            "Oracle AI Agent Memory managed schema setup was skipped for this FreeSQL run. "
            "The core notebook memory and retrieval tables already ran successfully."
        )

    captured_schema_output = agent_memory_stderr.getvalue()
    if "managed schema DDL" in captured_schema_output:
        agent_memory_schema_notes.append(
            "Package schema setup reported an expected hosted-database scheduler or schema privilege limitation; see the production privilege note above."
        )

    if agent_memory is not None:
        print("Oracle AI Agent Memory client is ready without external API billing.")
    else:
        print("Oracle AI Agent Memory client was not initialized for this FreeSQL run.")
        if agent_memory_init_error:
            print("Initialization detail:", agent_memory_init_error)

    for note in agent_memory_schema_notes:
        print(note)
else:
    print("Oracle AI Agent Memory client was not initialized. See package and schema readiness output above.")

AGENT_MEMORY_CLIENT_READY = agent_memory is not None

# %%
if agent_memory is not None:
    agent_memory_thread = agent_memory.create_thread(
        user_id=AGENT_MEMORY_USER_ID,
        agent_id=AGENT_MEMORY_AGENT_ID,
        metadata={
            "scenario": "Antigravity SQLcl MCP validation",
            "mode": "local no-billing agent memory demo",
            "sqlcl_connection_name": CONFIG["SQLCL_CONNECTION_NAME"],
            "antigravity_config_target": CONFIG["ANTIGRAVITY_MCP_CONFIG_PATH"] or "~/.gemini/config/mcp_config.json",
        },
    )

    antigravity_messages = [
        {
            "role": "user",
            "content": "I am validating Antigravity CLI with SQLcl MCP and Oracle AI Database.",
        },
        {
            "role": "assistant",
            "content": (
                "Antigravity should validate configuration, inspect MCP readiness, "
                "and avoid database writes unless explicitly approved."
            ),
        },
        {
            "role": "user",
            "content": (
                f"The current SQLcl saved connection alias is {CONFIG['SQLCL_CONNECTION_NAME']}."
            ),
        },
    ]

    message_ids = agent_memory_thread.add_messages(antigravity_messages)
    print("Created Agent Memory thread:", agent_memory_thread.thread_id)
    print("Stored messages:")
    for message_id in message_ids:
        print("-", message_id)
else:
    print("Skipped thread/message write because Agent Memory client is not initialized.")

# %%
memory_facts = [
    "Antigravity MCP configuration belongs in mcp_config.json, usually ~/.gemini/config/mcp_config.json.",
    "SQLcl MCP is launched with the SQLcl executable and args ['-mcp'].",
    f"The current SQLcl saved connection alias is {CONFIG['SQLCL_CONNECTION_NAME']}.",
    "TNS_ADMIN is optional when using a direct localhost Oracle DSN without wallet files.",
    "Antigravity should run read-only MCP checks before any DDL or DML.",
]

memory_ids = []
if agent_memory_thread is not None:
    memory_ids = [agent_memory_thread.add_memory(fact) for fact in memory_facts]
    print("Stored durable memories:")
    for memory_id in memory_ids:
        print("-", memory_id)
else:
    print("Skipped durable memory write because Agent Memory thread is not initialized.")

# %%
if agent_memory is not None:
    agent_memory_results = agent_memory.search(
        query="What should Antigravity remember before validating SQLcl MCP?",
        scope=SearchScope(user_id=AGENT_MEMORY_USER_ID, agent_id=AGENT_MEMORY_AGENT_ID),
        max_results=5,
    )

    seen_agent_memory_rows = set()
    agent_memory_rows = []
    for result in agent_memory_results:
        row_key = (result.record.record_type, result.content)
        if row_key in seen_agent_memory_rows:
            continue
        seen_agent_memory_rows.add(row_key)
        agent_memory_rows.append(
            {
                "record_type": result.record.record_type,
                "content": result.content,
            }
        )

    agent_memory_results_df = pd.DataFrame(agent_memory_rows)

    print("Oracle Agent Memory search results:")
    display_df(agent_memory_results_df)
else:
    agent_memory_results_df = pd.DataFrame(columns=["record_type", "content"])
    print("Skipped Agent Memory search because Agent Memory client is not initialized.")

# %%
retrieved_context = "\n".join(
    f"- [{row.record_type}] {row.content}"
    for row in agent_memory_results_df.itertuples(index=False)
)

if retrieved_context:
    antigravity_memory_prompt = f"""
You are Antigravity CLI helping validate SQLcl MCP with Oracle AI Database.

Use these retrieved Oracle Agent Memory facts:

{retrieved_context}

Work safely:
- prefer read-only checks first
- do not run DDL or DML unless the user explicitly approves
- keep SQLcl MCP and Oracle Database privileges as the execution boundary
""".strip()
else:
    antigravity_memory_prompt = (
        "Agent Memory package retrieval was not run. Use the notebook retrieval sections "
        "above, or create a dedicated Agent Memory database user and rerun Step 15."
    )

print(antigravity_memory_prompt)

# %%
agent_memory_capabilities = pd.DataFrame(
    [
        {
            "package_capability": "Memory client",
            "notebook_demo_object": "OracleAgentMemory(connection=db_pool, ...)",
            "architecture_role": "Use Oracle AI Database as the package-managed memory store.",
        },
        {
            "package_capability": "Threads",
            "notebook_demo_object": "agent_memory.create_thread()",
            "architecture_role": "Keep Antigravity CLI task messages grouped by thread.",
        },
        {
            "package_capability": "Durable memories",
            "notebook_demo_object": "agent_memory_thread.add_memory()",
            "architecture_role": "Persist reusable Antigravity setup facts and safety constraints.",
        },
        {
            "package_capability": "Scoped retrieval",
            "notebook_demo_object": "agent_memory.search(..., scope=SearchScope(...))",
            "architecture_role": "Retrieve memories by user and agent scope.",
        },
    ]
)

print("Where Oracle AI Agent Memory fits in this notebook:")
display_df(agent_memory_capabilities)
# Out:
# Where Oracle AI Agent Memory fits in this notebook:
#   package_capability                              notebook_demo_object  \
# 0      Memory client        OracleAgentMemory(connection=db_pool, ...)
# 1            Threads                      agent_memory.create_thread()
# 2   Durable memories                  agent_memory_thread.add_memory()
# 3   Scoped retrieval  agent_memory.search(..., scope=SearchScope(...))
#
#                                    architecture_role
# 0  Use Oracle AI Database as the package-managed ...
# 1  Keep Antigravity CLI task messages grouped by ...
# 2  Persist reusable Antigravity setup facts and s...
# 3         Retrieve memories by user and agent scope.

# %% [markdown]
# The important boundary is the same one described in the article:
#
# - Antigravity CLI uses MCP for controlled operational interaction.
# - Oracle AI Database stores durable memory, tool traces, and retrieval data. It is the storage and enforcement layer.
# - Oracle AI Agent Memory is the application-facing package API on top of Oracle AI Database. It handles threads, durable records, and scoped retrieval so application code does not manage every component directly.
# - This notebook uses a local deterministic embedder so the real package flow can be demonstrated without external model billing. Replace it with a supported embedding model for production semantic retrieval.
# - LangChain is orchestration glue for retrieval chains and tool coordination, useful when you need repeatable pipelines, but it is not the enforcement layer.

# %% [markdown]
# ## Optional Step 16 - LangChain Interoperability
#
# This section is optional. LangChain is shown only as an orchestration wrapper around retrieval results; it is not required for the core Oracle AI Database memory workflow.
#
# LangChain is useful here as a wrapper around retrieval behavior. It should not replace database permissions, SQLcl MCP boundaries, or operational logging.
#
# This section creates a tiny LangChain-compatible retriever using the Oracle AI Database-backed hybrid search function.

# %% [markdown]
# **DEVELOPER PATTERN: LangChain wrapper**
#
# Use this when: You want a reusable retrieval pipeline around Oracle-backed memory, but not a new enforcement layer.
#
# Minimal code: Wrap `hybrid_search()` in a LangChain-compatible retriever that returns documents.
#
# Expected output: Retrieval results formatted as LangChain documents for downstream chains.
#
# Adapt for your app: Add reranking, templating, and chain composition without moving privileges out of Oracle.
#
# Production note: LangChain is orchestration glue. Keep execution boundaries in MCP and access control in Oracle.

# %%
LANGCHAIN_READY = False
LANGCHAIN_ORACLEDB_READY = False
langchain_error = None
langchain_oracledb_error = None

try:
    from langchain_core.documents import Document
    from langchain_core.runnables import RunnableLambda
    LANGCHAIN_READY = True
except Exception as exc:
    langchain_error = str(exc)

try:
    import langchain_oracledb  # noqa: F401
    LANGCHAIN_ORACLEDB_READY = True
except Exception as exc:
    langchain_oracledb_error = str(exc)

if not LANGCHAIN_READY:
    class Document:
        def __init__(self, page_content: str, metadata: dict | None = None):
            self.page_content = page_content
            self.metadata = metadata or {}

    RunnableLambda = None

print("LangChain core:", "PASS" if LANGCHAIN_READY else f"WARN - {langchain_error}")
print("langchain-oracledb:", "PASS" if LANGCHAIN_ORACLEDB_READY else f"WARN - {langchain_oracledb_error}")
# Out:
# LangChain core: PASS
# langchain-oracledb: PASS

# %%
def oracle_memory_retriever(question: str, tenant_id: str = "TENANT_A", top_k: int = 4) -> list[Document]:
    rows = hybrid_search(question, tenant_id=tenant_id, top_k=top_k)
    documents = []
    for _, row in rows.iterrows():
        documents.append(
            Document(
                page_content=row["chunk_text"],
                metadata={
                    "chunk_id": int(row["chunk_id"]),
                    "tenant_id": row["tenant_id"],
                    "category": row["category"],
                    "title": row["title"],
                    "hybrid_score": float(row["hybrid_score"]),
                },
            )
        )
    return documents


def format_retrieval_context(question: str, docs: list[Document]) -> str:
    if not docs:
        return "INSUFFICIENT_CONTEXT: no tenant-scoped evidence was retrieved."
    lines = [f"Question: {question}", "", "Retrieved evidence:"]
    for idx, doc in enumerate(docs, start=1):
        lines.append(f"{idx}. {doc.metadata['title']} [{doc.metadata['category']}, score={doc.metadata['hybrid_score']}]")
        lines.append(f"   {doc.page_content}")
    return "\n".join(lines)


question = "Where does LangChain fit with Antigravity MCP and Oracle memory?"
docs = oracle_memory_retriever(question)
print(format_retrieval_context(question, docs))
# Out:
# Question: Where does LangChain fit with Antigravity MCP and Oracle memory?
#
# Retrieved evidence:
# 1. SQLcl MCP execution boundary [mcp_setup, score=0.9305]
#    Antigravity CLI should connect to Oracle AI Database through SQLcl MCP using sql -mcp. The assistant calls explicit tools instead of receiving unrestricted database access.
# 2. Antigravity memory versus Oracle memory [memory_model, score=0.9]
#    Antigravity memory improves assistant continuity, while Oracle memory provides durable, queryable, governed system memory across users, sessions, and tools.
# 3. Saved SQLcl connections for MCP [mcp_setup, score=0.3529]
#    SQLcl MCP relies on saved SQLcl connection profiles stored under the user connection store. MCP-compatible connections should persist the password with savepwd so Antigravity CLI can launch the server reproducibly.
# 4. Tool logging baseline [observability, score=0.2998]
# ...

# %% [markdown]
# ## Step 20 - MCP Validation Checklist
#
# This section is not an operational summary. It is a notebook validation checklist that shows which parts of the Antigravity MCP architecture are ready locally and which parts still need setup.
#
# The useful distinction is:
#
# - Oracle AI Database memory and retrieval can be validated from this notebook.
# - Live Antigravity MCP validation requires standalone SQLcl to be installed and referenced by `SQLCL_PATH`.
# - `DEMO_READY` means a portable notebook path is active. It is acceptable for this demo unless you specifically want the production Oracle Text path.

# %% [markdown]
# **DEVELOPER PATTERN: Live MCP validation**
#
# Use this when: You have already validated the Oracle memory layer and now want to confirm real Antigravity CLI plus SQLcl MCP behavior.
#
# Minimal code: Validate SQLcl, generate config preview, save a connection, restart Antigravity CLI, then run a read-only tool call.
#
# Expected output: Antigravity CLI sees SQLcl MCP tools and can execute a bounded read-only query through the saved connection.
#
# Adapt for your app: Expand from discovery to read-only diagnostics before enabling any write path.
#
# Production note: Keep this checklist separate from simulated notebook records so the notebook never over-claims live validation.

# %% [markdown]
# ### Optional live audit check after Antigravity
#
# After you run the read-only Antigravity + SQLcl MCP prompt, this optional check looks for database-side evidence of real MCP activity. It is intentionally best-effort: `DBTOOLS$MCP_LOG` and `V$SESSION` visibility depends on SQLcl, database version, grants, and whether the session is still active. If the queries return `ACTION_NEEDED` or an access error, keep the simulated teaching logs separate from live MCP proof.

# %%
def optional_live_mcp_audit_check():
    audit_results = []

    try:
        mcp_log_objects = run_sql("""
            SELECT owner, table_name
            FROM all_tables
            WHERE table_name = 'DBTOOLS$MCP_LOG'
            ORDER BY owner, table_name
        """)
        audit_results.append({
            "check": "DBTOOLS$MCP_LOG visibility",
            "status": "READY" if not mcp_log_objects.empty else "ACTION_NEEDED",
            "detail": "MCP log table is visible to this user." if not mcp_log_objects.empty else "No visible DBTOOLS$MCP_LOG table for this user.",
        })
        if not mcp_log_objects.empty:
            print("Visible DBTOOLS$MCP_LOG objects:")
            display_df(mcp_log_objects)
            try:
                print("Recent DBTOOLS$MCP_LOG rows:")
                display_df(run_sql("SELECT * FROM DBTOOLS$MCP_LOG FETCH FIRST 10 ROWS ONLY"))
            except Exception as log_exc:
                print("DBTOOLS$MCP_LOG row query unavailable:", log_exc)
    except Exception as exc:
        audit_results.append({
            "check": "DBTOOLS$MCP_LOG visibility",
            "status": "ACTION_NEEDED",
            "detail": f"Could not inspect DBTOOLS$MCP_LOG: {exc}",
        })

    try:
        session_df = run_sql("""
            SELECT username, program, module, action, status, machine
            FROM v$session
            WHERE username IS NOT NULL
              AND (
                    LOWER(program) LIKE '%sqlcl%'
                 OR LOWER(module) LIKE '%mcp%'
                 OR LOWER(action) LIKE '%mcp%'
                 OR LOWER(program) LIKE '%antigravity%'
              )
            ORDER BY username, program, module, action
            FETCH FIRST 10 ROWS ONLY
        """)
        audit_results.append({
            "check": "V$SESSION module/action visibility",
            "status": "READY" if not session_df.empty else "ACTION_NEEDED",
            "detail": "Potential live SQLcl MCP session metadata found." if not session_df.empty else "No matching live session is visible; run this soon after the Antigravity test or request catalog privileges.",
        })
        if not session_df.empty:
            print("Potential live SQLcl MCP sessions:")
            display_df(session_df)
    except Exception as exc:
        audit_results.append({
            "check": "V$SESSION module/action visibility",
            "status": "ACTION_NEEDED",
            "detail": f"Could not inspect V$SESSION: {exc}",
        })

    audit_df = pd.DataFrame(audit_results)
    print("Optional live MCP audit check:")
    display_df(audit_df)
    return audit_df

live_mcp_audit_df = optional_live_mcp_audit_check()
# Out:
# Optional live MCP audit check:
#                                 check         status  \
# 0          DBTOOLS$MCP_LOG visibility  ACTION_NEEDED
# 1  V$SESSION module/action visibility  ACTION_NEEDED
#
#                                               detail
# 0    No visible DBTOOLS$MCP_LOG table for this user.
# 1  Could not inspect V$SESSION: ORA-00942: table ...

# %%
diagnostic_checks = [
    {
        "check_name": "SQLCL_DISCOVERY",
        "status": "PASS" if SQLCL_MCP_READY else "ACTION_NEEDED",
        "detail": "Standalone SQLcl MCP runtime validated." if SQLCL_MCP_READY else summarize_sqlcl_issue(sqlcl_check),
        "notebook_role": "Antigravity MCP launch prerequisite",
        "next_step": "No action." if SQLCL_MCP_READY else "Install standalone SQLcl 25.2+ and set SQLCL_PATH.",
    },
    {
        "check_name": "JAVA_RUNTIME",
        "status": "PASS" if java_check["ok"] else "ACTION_NEEDED",
        "detail": java_first_line,
        "notebook_role": "SQLcl MCP runtime dependency",
        "next_step": "No action." if java_check["ok"] else "Install Oracle JRE 17 or 21.",
    },

    {
        "check_name": "SQLCL_CONNECTION_ALIAS",
        "status": "PASS" if SQLCL_CONNECTION_READY else "ACTION_NEEDED",
        "detail": "Saved SQLcl connection alias validated." if SQLCL_CONNECTION_READY else f"Saved connection alias {CONFIG['SQLCL_CONNECTION_NAME']} was not validated.",
        "notebook_role": "Antigravity CLI SQLcl MCP connection profile",
        "next_step": "No action." if SQLCL_CONNECTION_READY else "Run conn -save <alias> -savepwd <user>/<password>@<dsn>, then rerun Step 2b.",
    },
    {
        "check_name": "ANTIGRAVITY_MCP_CONFIG_PREVIEW",
        "status": "PASS",
        "detail": "Sanitized Antigravity MCP config preview generated.",
        "notebook_role": "Antigravity CLI tool registration artifact",
        "next_step": "Copy into Antigravity MCP config after SQLcl is validated.",
    },
    {
        "check_name": "ORACLE_AI_DATABASE_CONNECTION",
        "status": "PASS",
        "detail": "Connected with configured .env credentials; DSN is not displayed.",
        "notebook_role": "Oracle AI Database memory substrate",
        "next_step": "No action for this notebook.",
    },
    {
        "check_name": "ORACLE_TEXT",
        "status": "PASS" if ORACLE_TEXT_READY else "DEMO_READY",
        "detail": "Oracle Text lexical retrieval path ready." if ORACLE_TEXT_READY else "Portable LIKE lexical retrieval path active.",
        "notebook_role": "Lexical retrieval path",
        "next_step": "Optional: grant Oracle Text privileges when production lexical ranking is required.",
    },
    {
        "check_name": "NATIVE_VECTOR",
        "status": "PASS" if NATIVE_VECTOR_READY else "FALLBACK",
        "detail": "Native VECTOR column search path ready." if NATIVE_VECTOR_READY else "Portable cosine fallback active.",
        "notebook_role": "Oracle AI Database vector execution path",
        "next_step": "Use native VECTOR indexes for larger datasets.",
    },
    {
        "check_name": "DEMO_EMBEDDINGS",
        "status": "DEMO_READY",
        "detail": "Deterministic local embeddings are active for repeatable notebook results; replace demo_embed() for production semantics.",
        "notebook_role": "Portable semantic-ranking demo input",
        "next_step": "Replace with production embedding model output before treating scores as semantic quality.",
    },
    {
        "check_name": "ORACLE_AGENT_MEMORY_PACKAGE",
        "status": "PASS" if AGENT_MEMORY_CLIENT_READY else "OPTIONAL",
        "detail": "Oracle Agent Memory client initialized." if AGENT_MEMORY_CLIENT_READY else "oracleagentmemory package is installed, but managed schema setup was skipped for this FreeSQL run.",
        "notebook_role": "Optional Oracle AI Database-backed agent memory API",
        "next_step": "Use package APIs for managed memory workflows." if AGENT_MEMORY_CLIENT_READY else "Use the core notebook retrieval tables, or rerun package-backed Step 15 with the required managed-schema privileges.",
    },
    {
        "check_name": "LANGCHAIN_CORE",
        "status": "PASS" if LANGCHAIN_READY else "OPTIONAL",
        "detail": "LangChain core available." if LANGCHAIN_READY else "LangChain core unavailable.",
        "notebook_role": "Optional retrieval wrapper",
        "next_step": "Use only for orchestration; keep enforcement in Oracle AI Database privileges.",
    },
    {
        "check_name": "LANGCHAIN_ORACLEDB",
        "status": "PASS" if LANGCHAIN_ORACLEDB_READY else "OPTIONAL",
        "detail": "langchain-oracledb available." if LANGCHAIN_ORACLEDB_READY else "langchain-oracledb unavailable.",
        "notebook_role": "Optional Oracle AI Database vector integration",
        "next_step": "Use when replacing demo embeddings with a real vector store.",
    },
]

cursor.execute("DELETE FROM antigravity_validation_checks")
for check in diagnostic_checks:
    cursor.execute(
        """
        INSERT INTO antigravity_validation_checks (check_name, status, detail)
        VALUES (:check_name, :status, :detail)
        """,
        {k: check[k] for k in ["check_name", "status", "detail"]},
    )
connection.commit()

validation_df = pd.DataFrame(diagnostic_checks)
validation_df = validation_df[["check_name", "status", "notebook_role", "detail", "next_step"]]

print("MCP validation checklist:")
display_df(validation_df, max_rows=len(validation_df))
# Out:
# MCP validation checklist:
#                         check_name      status  \
# 0                  SQLCL_DISCOVERY        PASS
# 1                     JAVA_RUNTIME        PASS
# 2           SQLCL_CONNECTION_ALIAS        PASS
# 3   ANTIGRAVITY_MCP_CONFIG_PREVIEW        PASS
# 4    ORACLE_AI_DATABASE_CONNECTION        PASS
# 5                      ORACLE_TEXT  DEMO_READY
# 6                    NATIVE_VECTOR        PASS
# 7                  DEMO_EMBEDDINGS  DEMO_READY
# 8      ORACLE_AGENT_MEMORY_PACKAGE    OPTIONAL
# 9                   LANGCHAIN_CORE        PASS
# 10              LANGCHAIN_ORACLEDB        PASS
#
#                                         notebook_role  \
# 0                 Antigravity MCP launch prerequisite
# 1                        SQLcl MCP runtime dependency
# 2        Antigravity CLI SQLcl MCP connection profile
# 3          Antigravity CLI tool registration artifact
# 4                 Oracle AI Database memory substrate
# ...

# %% [markdown]
# ## Step 21 - Notebook Results Snapshot
#
# This final snapshot summarizes what the notebook proved technically:
#
# - the Oracle AI Database memory schema was created,
# - Antigravity/MCP-style tool traces were stored,
# - retrieval evidence was generated,
# - LangChain could consume the retrieval layer,
# - and local Antigravity CLI validation is separated from database-memory validation.

# %%
summary = run_sql("""
SELECT 'conversation_rows' AS metric, COUNT(*) AS value FROM antigravity_conversational_memory
UNION ALL
SELECT 'mcp_tool_logs' AS metric, COUNT(*) AS value FROM antigravity_tool_logs
UNION ALL
SELECT 'knowledge_chunks' AS metric, COUNT(*) AS value FROM antigravity_kb_chunks
UNION ALL
SELECT 'validation_pass_checks' AS metric, COUNT(*) AS value FROM antigravity_validation_checks WHERE status = 'PASS'
UNION ALL
SELECT 'validation_demo_ready_checks' AS metric, COUNT(*) AS value FROM antigravity_validation_checks WHERE status = 'DEMO_READY'
UNION ALL
SELECT 'validation_fallback_checks' AS metric, COUNT(*) AS value FROM antigravity_validation_checks WHERE status = 'FALLBACK'
UNION ALL
SELECT 'validation_action_needed' AS metric, COUNT(*) AS value FROM antigravity_validation_checks WHERE status = 'ACTION_NEEDED'
""")

snapshot = pd.DataFrame([
    {"layer": "Antigravity MCP config", "result": "generated", "evidence": "Sanitized mcp_config.json preview is available."},
    {"layer": "SQLcl MCP runtime", "result": "ready" if SQLCL_MCP_READY else "needs local SQLcl path", "evidence": "Required for live Antigravity CLI tool use."},
    {"layer": "SQLcl saved connection", "result": "ready" if SQLCL_CONNECTION_READY else "needs saved alias", "evidence": "Antigravity CLI uses this SQLcl connection profile through MCP."},
    {"layer": "Oracle AI Database memory", "result": "ready", "evidence": "Conversation, tool log, and knowledge memory tables are populated with simulated teaching data."},
    {"layer": "Oracle AI Agent Memory package", "result": "ready" if AGENT_MEMORY_CLIENT_READY else "optional", "evidence": "Application-facing memory API on top of Oracle AI Database; optional on FreeSQL when managed-schema privileges are unavailable."},
    {"layer": "Lexical search", "result": "ready" if ORACLE_TEXT_READY else "demo ready", "evidence": "Oracle Text is active." if ORACLE_TEXT_READY else "Portable LIKE retrieval is active for the notebook demo."},
    {"layer": "Native VECTOR execution path", "result": "ready" if NATIVE_VECTOR_READY else "fallback", "evidence": "Oracle AI Database VECTOR column search is active." if NATIVE_VECTOR_READY else "Portable Python cosine ranking is active."},
    {"layer": "Demo embeddings", "result": "demo ready", "evidence": "Deterministic local embeddings make results reproducible; replace with production model embeddings for semantic quality."},
    {"layer": "Hybrid retrieval", "result": "ready", "evidence": "Lexical + vector signals were combined into evidence ranking."},
    {"layer": "LangChain wrapper", "result": "ready" if LANGCHAIN_READY else "optional", "evidence": "Oracle AI Database retrieval can be returned as documents."},
])

print("Notebook results snapshot:")
display_df(snapshot, max_rows=len(snapshot))
print("\nMetric counts:")
display_df(summary, max_rows=len(summary))
# Out:
# Notebook results snapshot:
#                             layer      result  \
# 0          Antigravity MCP config   generated
# 1               SQLcl MCP runtime       ready
# 2          SQLcl saved connection       ready
# 3       Oracle AI Database memory       ready
# 4  Oracle AI Agent Memory package    optional
# 5                  Lexical search  demo ready
# 6    Native VECTOR execution path       ready
# 7                 Demo embeddings  demo ready
# 8                Hybrid retrieval       ready
# 9               LangChain wrapper       ready
#
#                                             evidence
# 0    Sanitized mcp_config.json preview is available.
# 1        Required for live Antigravity CLI tool use.
# 2  Antigravity CLI uses this SQLcl connection pro...
# 3  Conversation, tool log, and knowledge memory t...
# 4  Application-facing memory API on top of Oracle...
# 5  Portable LIKE retrieval is active for the note...
# ...

# %% [markdown]
# ## Optional Cleanup
#
# Leave `RUN_CLEANUP = False` if you want to inspect the tables after the notebook finishes. Set it to `True` only when you want to remove the demo objects.

# %%
RUN_CLEANUP = False

if RUN_CLEANUP:
    safe_drop_index("ANTIGRAVITY_KB_TEXT_IDX")
    safe_drop_index("ANTIGRAVITY_KB_VECTOR_IDX")
    for table in [
        "ANTIGRAVITY_VALIDATION_CHECKS",
        "ANTIGRAVITY_KB_CHUNKS",
        "ANTIGRAVITY_TOOL_LOGS",
        "ANTIGRAVITY_CONVERSATIONAL_MEMORY",
    ]:
        safe_drop_table(table)
    print("Demo objects removed.")
else:
    print("Cleanup skipped. Demo tables remain available for inspection.")
# Out:
# Cleanup skipped. Demo tables remain available for inspection.

# %% [markdown]
# After the notebook completes, the two artifacts you need for live Antigravity setup are:
#
# - **MCP config preview**: `antigravity_sqlcl_mcp_config.preview.json` in your project root. Review and copy the `mcpServers.sqlcl` block into `.agents/mcp_config.json` or `~/.gemini/config/mcp_config.json`.
# - **Connection alias**: the value of `SQLCL_CONNECTION_NAME` from your `.env` (default: `antigravity_mcp`) is the saved SQLcl connection Antigravity will use through SQLcl MCP.

# %% [markdown]
# ## Quick Validation Snapshot
#
# Use this final pass before moving from the notebook to Antigravity:
#
# 1. Notebook execution finished without error outputs.
# 2. SQLcl is discoverable and can launch with `-mcp`.
# 3. The saved SQLcl connection `antigravity_mcp` validates with `SQLcl -name`.
# 4. `antigravity_sqlcl_mcp_config.preview.json` exists and contains the `mcpServers.sqlcl` block.
# 5. Open Antigravity's MCP manager with `/mcp`, copy the `mcpServers.sqlcl` block into `~/.gemini/config/mcp_config.json` or `.agents/mcp_config.json`, reload MCP servers, then ask a read-only question.
#
# Suggested first Antigravity prompt:
#
# ```text
# Using the SQLcl MCP server, list the available Oracle connections and run SELECT USER FROM dual. Do not run DDL or DML.
# ```

# %% [markdown]
# ## Summary
#
# This notebook demonstrates the core workflow from the companion article:
# - Antigravity CLI uses MCP tools instead of implicit database access.
# - SQLcl MCP is the explicit Oracle AI Database execution boundary.
# - Oracle AI Database stores durable memory, tool traces, and retrieval evidence: it is the storage and enforcement layer.
# - Oracle AI Agent Memory is the application-facing Python package that sits on top of Oracle AI Database. Steps 4 through 14 build what the package manages, so the mechanics are visible before the package abstraction is introduced in Step 15.
# - Vector search and lexical search are combined into hybrid retrieval.
# - LangChain wraps retrieval where orchestration is useful, but does not replace database-level enforcement.
#
# The remaining local setup items, if any, are SQLcl discovery and the saved SQLcl connection alias. If the notebook reports `ACTION_NEEDED`, set `SQLCL_PATH` to standalone SQLcl, save the `antigravity_mcp` connection with `-savepwd`, and rerun the validation cells before testing the flow inside Antigravity CLI.
#
# The deterministic embeddings in this notebook are only for the portable demo path; replace them with production embedding model outputs before using retrieval scores as real semantic quality signals.
